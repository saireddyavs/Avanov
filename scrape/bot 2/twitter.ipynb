# %%
# import twint

# c = twint.Config()

# c.Search=input("Enter sentence::")
# c.Limit = 100
# c.Email=True

# c.Store_csv = True
# c.Output = "none"
# twint.run.Search(c)

# %% [markdown]
# # 2.prediction

# %%
import pandas as pd

df=pd.read_csv("none/tweets.csv")

print(df.columns)
# question.isnull().any()
# question.columns
import datetime as dt
import nltk
start = dt.datetime.now()
sno=nltk.stem.SnowballStemmer("english")
i=0
str1=""
final_string=[]
all_positive_words=[]
all_negative_words=[]
s=""
from nltk.corpus import stopwords
stop=set(stopwords.words('english'))
excluding = ['against','not','don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't",
             'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 
             'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",'shouldn', "shouldn't", 'wasn',
             "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
stop = [words for words in stop if words not in excluding]

import re
def cleanhtml(sentence):
    cleanr=re.compile('<.*>')
    cleantext=re.sub(cleanr,'',sentence)
    return cleantext
def cleanpunc(sentence):
    cleaned=re.sub(r'[?|!|\'|"|#]',r' ',sentence) #seee \' and combination
    cleaned=re.sub(r'[.|,|)|/|\|(]',r' ',cleaned)
    return cleaned
print(sno.stem("tasty"))#checking the rootword of tasty

print(sno)


import ipywidgets as widgets
def preprocess1(X):
    final_string=[]
    

    for sent in X:
        filterd_sentence=[]
        
        sent=str(sent)

        sent=cleanhtml(sent)
#         print(sent)
        for w in sent.split():
            for cleaned_words in cleanpunc(w).split():
                if((cleaned_words.isalpha())&(len(cleaned_words)>2)):
                    if(cleaned_words.lower() not in stop):
                        s=(sno.stem(cleaned_words.lower())).encode("utf8")
                        filterd_sentence.append(s)

                    else:
                        continue
                else:
                    continue

        str1= b" ".join(filterd_sentence)
        final_string.append(str1)
#         i=i+1
    return final_string


def preprocess(X):
    final_string=[]
    X=[X]

    for sent in X:
        filterd_sentence=[]
        
        sent=str(sent)

        sent=cleanhtml(sent)
#         print(sent)
        for w in sent.split():
            for cleaned_words in cleanpunc(w).split():
                if((cleaned_words.isalpha())&(len(cleaned_words)>2)):
                    if(cleaned_words.lower() not in stop):
                        s=(sno.stem(cleaned_words.lower())).encode("utf8")
                        filterd_sentence.append(s)

                    else:
                        continue
                else:
                    continue

        str1= b" ".join(filterd_sentence)
        final_string.append(str1)
#         i=i+1
    return final_string



import pickle
from keras.preprocessing import sequence
def find_word_index(row,word_index_dict):  
    holder = []
    for word in row.split():
        if word in word_index_dict:
            holder.append(word_index_dict[word]) 
        else:
            holder.append(0)            
    return holder
def predict_lstm(x):
    x=preprocess1(x)
#     print(x)
#     with open('model_lstm.pkl', 'rb') as f:
#         model = pickle.load(f)

#     print(model.predict[x])
    with open('label_transform.pkl', 'rb') as f:
        encoder= pickle.load(f)
        
    from keras.models import load_model
    model = load_model('LSTM_1.ckpt')
        
    with open('word_index_dict.pkl', 'rb') as f:
        word_index_dict= pickle.load(f)
        
    text=[]
    for sent in x:
        text.append(find_word_index(sent,word_index_dict))
        
        
        
  
    #print(len(x),len(text))  
    x=sequence.pad_sequences(text, maxlen=500)
    
    
        
    
    
    
    
    pred_prob=model.predict(x)
    
#     print(pred_prob)
#     print(encoder.classes_)
    
    
    sentiment=[]
    
#     print(encoder.inverse_transform(pred_prob))
    
    preds=encoder.inverse_transform(pred_prob)
    
    for pre in preds:
        if pre==1:
            sentiment.append("Strongly Negative")
        if pre==2:
            sentiment.append("Weekly Negative")
        if pre==3:
            sentiment.append("Neutral")
        if pre==4:
            sentiment.append("Weekly Positive")
        if pre==5:
            sentiment.append("Strongly Positive")
    
  
            
        
    


    
    
#     print("output::",pred)
    
        
    return [sentiment,pred_prob]
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'mentions', 'urls',
#        'photos', 'replies_count', 'retweets_count', 'likes_count', 'hashtags',
#        'cashtags', 'link', 'retweet', 'quote_url', 'video', 'near', 'geo',
#        'source', 'user_rt_id', 'user_rt', 'retweet_id', 'reply_to',
#        'retweet_date'],
#       dtype='object')
# tasti
# <nltk.stem.snowball.SnowballStemmer object at 0x0000014110BE8CF8>
# Using TensorFlow backend.
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df['cleaned']=df.tweet.apply(lambda x:preprocess(x))

# %%
# df.head()
q=predict_lstm(list(df.cleaned))
df['sentiment']=q[0]


import numpy as np

df['confidence']=q[1].tolist()
# Out:
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
df.drop('cleaned', axis=1, inplace=True)
df = df.astype(str)

# %%
df.shape
# Out:
# (857, 33)

# %%
df.loc[0].values
# Out:
# array(['1108275561988648961', '1108275561988648961', '1553068459000',
#        '2019-03-20', '13:24:19', 'India Standard Time', '387203447',
#        'mdrafiq8', 'Rafiq', 'nan',
#        'Sir I am also your age sir but I am now jobless sir I am rafiq from india sir searching job in abroad I love UAE not get any job .2 years I am jobless sir I am not fraud any job\nMy whatsapp +919789629328\nMY MAIL ID \nmdrafiq8@gmail.com\nPlease I am waiting for your reply sir  https://twitter.com/NoahUrrea/status/1108101567784386561\xa0…',
#        '[]',
#        "['https://twitter.com/NoahUrrea/status/1108101567784386561']",
#        '[]', '0', '0', '0', '[]', '[]',
#        'https://twitter.com/MdRafiq8/status/1108275561988648961', 'False',
#        'https://twitter.com/NoahUrrea/status/1108101567784386561', '0',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        "[{'user_id': '387203447', 'username': 'MdRafiq8'}]", 'nan',
#        'Strongly Positive',
#        '[0.23646551370620728, 0.12241610884666443, 0.09577363729476929, 0.10064378380775452, 0.34280383586883545]'],
#       dtype=object)

# %%
# mycursor.execute('INSERT INTO Twitter(id , conversation_id , created_at , date , time , timezone ,user_id  , username , name , place , tweet , mentions , urls ,photos , replies_count , retweets_count , likes_count , hashtags ,cashtags , link , retweet , quote_url  , video , near , geo ,source , user_rt_id , user_rt ,retweet_id , reply_to ,retweet_date)' \
#           'VALUES("%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s")', 
#           list(df[-1:3].values[0]))

# %%
# list(df[1].values[0])

# %%
# mycursor.execute('INSERT INTO Twitter(id , conversation_id , created_at , date , time , timezone ,user_id  , username , name , place , tweet , mentions , urls ,photos , replies_count , retweets_count , likes_count , hashtags ,cashtags , link , retweet , quote_url  , video , near , geo ,source , user_rt_id , user_rt ,retweet_id , reply_to ,retweet_date)' \
#           'VALUES("%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s")', 
#           list(df.loc[0].values))

# %% [markdown]
# # 3.Stroing in DataBase

# %%
import mysql.connector as mysql

mydb = mysql.connect(
  host="127.0.0.1",
  user="sai",
  passwd="rgukt123",
    port="3309"
)

print(mydb)

# import pandas as pd

# df=pd.read_csv("none/tweets.csv")

# print(df.columns)

mycursor = mydb.cursor()



try:
    mycursor.execute("CREATE DATABASE bot")
except:
    print("Database named bot already exists")




mydb = mysql.connect(
  host="localhost",
  user="root",
  passwd="rgukt123",
  database="bot",
    port="3309"
    
)


mycursor = mydb.cursor()

sql = "DROP TABLE IF EXISTS Twitter"

mycursor.execute(sql) 

mycursor.execute("CREATE TABLE Twitter (id VARCHAR(255), conversation_id VARCHAR(255), created_at VARCHAR(255), date VARCHAR(255), time VARCHAR(255), timezone VARCHAR(255),user_id VARCHAR(255) , username VARCHAR(255), name VARCHAR(255), place VARCHAR(255), tweet TEXT, mentions TEXT, urls text,photos VARCHAR(255), replies_count VARCHAR(255), retweets_count text, likes_count text, hashtags text,cashtags text, link text, retweet text, quote_url text , video text, near text, geo text,source text, user_rt_id text, user_rt text,retweet_id text, reply_to TEXT,retweet_date text,sentiment text,confidence text)");






for i in df.index:
    if i==0:
        continue
    
    mycursor.execute('INSERT INTO Twitter(id , conversation_id , created_at , date , time , timezone ,user_id  , username , name , place , tweet , mentions , urls ,photos , replies_count , retweets_count , likes_count , hashtags ,cashtags , link , retweet , quote_url  , video , near , geo ,source , user_rt_id , user_rt ,retweet_id , reply_to ,retweet_date,sentiment,confidence)' \
          'VALUES("%s","%s","%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s", "%s", "%s","%s", "%s", "%s")', 
          list(df[i-1:i].values[0]))
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001413043F748>
# Database named bot already exists

# %% [markdown]
# # 4.Retriving Data From DataBase

# %%
mycursor.execute("SELECT * FROM Twitter")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
  print("*"*100)
# Out:
# ("'1108275561988648961'", "'1108275561988648961'", "'1553068459000'", "'2019-03-20'", "'13:24:19'", "'India Standard Time'", "'387203447'", "'mdrafiq8'", "'Rafiq'", "'nan'", "'Sir I am also your age sir but I am now jobless sir I am rafiq from india sir searching job in abroad I love UAE not get any job .2 years I am jobless sir I am not fraud any job\nMy whatsapp +919789629328\nMY MAIL ID \nmdrafiq8@gmail.com\nPlease I am waiting for your reply sir  https://twitter.com/NoahUrrea/status/1108101567784386561\xa0…'", "'[]'", "'['https://twitter.com/NoahUrrea/status/1108101567784386561']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/MdRafiq8/status/1108275561988648961'", "'False'", "'https://twitter.com/NoahUrrea/status/1108101567784386561'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '387203447', 'username': 'MdRafiq8'}]'", "'nan'", "'Strongly Positive'", "'[0.23646551370620728, 0.12241610884666443, 0.09577363729476929, 0.10064378380775452, 0.34280383586883545]'")
# ****************************************************************************************************
# ("'1108102621737304064'", "'1108102621737304064'", "'1553027227000'", "'2019-03-20'", "'01:57:07'", "'India Standard Time'", "'143736875'", "'tripindia'", "'Ajay Tripathi'", "'nan'", "'In Sleeper Class more than 300 Person's No one to look after toilets full of 4 persons/ There in no way to use toilet\nMany pikpokiters \nOnly one thing was ok that train running only 40 Minutes late\nGreetings from\nTripathi\nKalka mail 12311/S9/28\nS9 /28\n19/3/2019\nI love my india  pic.twitter.com/9CeTmt4ata'", "'[]'", "'[]'", "'['https://pbs.twimg.com/media/D2DFb-PU0AA8bTv.jpg', 'https://pbs.twimg.com/media/D2DFb-RUwAAJDMZ.jpg', 'https://pbs.twimg.com/media/D2DFb-QUYAAoUCD.jpg']'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/tripindia/status/1108102621737304064'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '143736875', 'username': 'tripindia'}]'", "'nan'", "'Strongly Positive'", "'[0.1804354190826416, 0.1878613531589508, 0.18127229809761047, 0.15192297101020813, 0.26623207330703735]'")
# ****************************************************************************************************
# ("'1106955286227623936'", "'1106851043995017216'", "'1552753681000'", "'2019-03-16'", "'21:58:01'", "'India Standard Time'", "'959123606272962561'", "'himanshu5323'", "'Himanshu Singh'", "'nan'", "'The Hollywood Theme Park Was Amazing I Can Imagine And Feel That Park From India Without Going There. I Am And Other People Are You Lucky They Are Getting Free Trips Without Going Anywhere Without Spending Money. I Love You Nikhil Bhai \nEmail : thehimanshu.hs@gmail.com\n#MNYTFF'", "'['emnikhil', 'youtubefanfest', 'ytcreatorsindia']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'['#mnytff']'", "'[]'", "'https://twitter.com/Himanshu5323/status/1106955286227623936'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '959123606272962561', 'username': 'Himanshu5323'}, {'user_id': '158585516', 'username': 'emNikhil'}, {'user_id': '1371843906', 'username': 'YouTubeFanFest'}, {'user_id': '2981263152', 'username': 'YTCreatorsIndia'}]'", "'nan'", "'Strongly Positive'", "'[0.009617328643798828, 0.01744338870048523, 0.021847516298294067, 0.10349273681640625, 0.8742574453353882]'")
# ****************************************************************************************************
# ("'1099769512138887168'", "'1099769512138887168'", "'1551040459000'", "'2019-02-25'", "'02:04:19'", "'India Standard Time'", "'1009453311790108672'", "'anurag03494047'", "'Anurag'", "'nan'", "'#Hrithik Hrithik Roshan Tumhari Kiran I love you good Night Chart dekh lena I love you so much💋💋💋💋💋💋💋💋😅😅😘😘😘😘😘😅😘😅😅😅😅👌👌🌹😅😅💋 India direct mail Dekho Yaad Aane Se Pehle Tum Aa Jaya Karo Yaad Na Aaya Karo  pic.twitter.com/E3nC4PkFYG'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'1'", "'['#hrithik']'", "'[]'", "'https://twitter.com/Anurag03494047/status/1099769512138887168'", "'False'", "'nan'", "'1'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1009453311790108672', 'username': 'Anurag03494047'}]'", "'nan'", "'Strongly Negative'", "'[0.8780314922332764, 0.10572350025177002, 0.024189263582229614, 0.0076194703578948975, 0.012665212154388428]'")
# ****************************************************************************************************
# ("'1096461607192969216'", "'1096461607192969216'", "'1550251793000'", "'2019-02-15'", "'22:59:53'", "'India Standard Time'", "'236984912'", "'sacheen8'", "'Chowkidar Sacheen Suvarna'", "'nan'", "'I m now 40plus ,I m fit , I m ready for Kashmir, i want to serve my mother as soldier and fight against terrorism in Kashmir. If I have to sacrifice my life I love to my mail me address is sacheen.suvarna8@gmail ...any thing for my LOVE (INDIA)'", "'[]'", "'[]'", "'[]'", "'1'", "'0'", "'1'", "'[]'", "'[]'", "'https://twitter.com/sacheen8/status/1096461607192969216'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '236984912', 'username': 'sacheen8'}]'", "'nan'", "'Strongly Positive'", "'[0.0032539963722229004, 0.01346445083618164, 0.038857102394104004, 0.2548140287399292, 0.6052083373069763]'")
# ****************************************************************************************************
# ("'1096041621345325057'", "'1096037555513032704'", "'1550151660000'", "'2019-02-14'", "'19:11:00'", "'India Standard Time'", "'1051599121075777537'", "'aoe_love_mail'", "'Parker | Alastor loving hours'", "'nan'", "'Fun fact, I'm from india 👀but tbh i love your first name xD'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/Aoe_love_mail/status/1096041621345325057'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1051599121075777537', 'username': 'Aoe_love_mail'}]'", "'nan'", "'Strongly Positive'", "'[0.10218730568885803, 0.14882302284240723, 0.18887409567832947, 0.1499088704586029, 0.30847638845443726]'")
# ****************************************************************************************************
# ("'1090144661962928128'", "'1090085174161764353'", "'1548745715000'", "'2019-01-29'", "'12:38:35'", "'India Standard Time'", "'985919707566956545'", "'jitendr37741447'", "'Jiitendra'", "'nan'", "'#केजरीवाल #NarendraModi\nI love my children that is why, will vote modiji not loot khasot party or thags of india'", "'['indiatoday', 'indiatodayflash', 'pankajjainclick', 'mail_today']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'['#केजरीवाल', '#narendramodi']'", "'[]'", "'https://twitter.com/Jitendr37741447/status/1090144661962928128'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '985919707566956545', 'username': 'Jitendr37741447'}, {'user_id': '19897138', 'username': 'IndiaToday'}, {'user_id': '1073676020', 'username': 'IndiaTodayFLASH'}, {'user_id': '4364503754', 'username': 'PankajJainClick'}, {'user_id': '2904188772', 'username': 'mail_today'}]'", "'nan'", "'Strongly Negative'", "'[0.25039395689964294, 0.18545305728912354, 0.08537665009498596, 0.09830090403556824, 0.2461724579334259]'")
# ****************************************************************************************************
# ("'1083365752722190336'", "'1083365752722190336'", "'1547129498000'", "'2019-01-10'", "'19:41:38'", "'India Standard Time'", "'300678124'", "'pavankumar102'", "'pavan kumar'", "'nan'", "'@GoogleIndia please introduce social media app\nexample:what's app,snapchat \ngoogle product is good i love google products \nplease add the payment option in gmail auto reply option and introduce google fi in india.....'", "'['googleindia']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/pavankumar102/status/1083365752722190336'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '300678124', 'username': 'pavankumar102'}, {'user_id': '94530194', 'username': 'GoogleIndia'}]'", "'nan'", "'Strongly Positive'", "'[0.05380961298942566, 0.051473140716552734, 0.059049904346466064, 0.14549168944358826, 0.6906336545944214]'")
# ****************************************************************************************************
# ("'1081892325368840193'", "'1081683867277447169'", "'1546778205000'", "'2019-01-06'", "'18:06:45'", "'India Standard Time'", "'1020207572878544896'", "'taylerplays'", "'Tayler'", "'nan'", "'Quig is a great time in India today evening or night sweet heart and I love my family members happy Diwali my friends are my everything will come at your home at the same time that we have the right to education system requirements of India news channel number and email address.'", "'['realquig']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/TaylerPlays/status/1081892325368840193'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1020207572878544896', 'username': 'TaylerPlays'}, {'user_id': '2350827685', 'username': 'realQuig'}]'", "'nan'", "'Strongly Positive'", "'[0.152479887008667, 0.12432855367660522, 0.13772693276405334, 0.1842477023601532, 0.4869084060192108]'")
# ****************************************************************************************************
# ("'1075250121254682624'", "'1075047208704196613'", "'1545194580000'", "'2018-12-19'", "'10:13:00'", "'India Standard Time'", "'751123153418539008'", "'ssivaganesh1986'", "'sivaganesh'", "'nan'", "'I am a indian but I love america ,currently I am staying in india ,I have no money ,my dream is i settled to America. If any one help to me .I have a passport ,I don't have money ,visa .my mail id sivasqlserverdba5 @gmail.com ,please help me to see the america .Marry Chris miss .'", "'['flotus', 'potus', 'gmail']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/ssivaganesh1986/status/1075250121254682624'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '751123153418539008', 'username': 'ssivaganesh1986'}, {'user_id': '818876014390603776', 'username': 'FLOTUS'}, {'user_id': '822215679726100480', 'username': 'POTUS'}, {'user_id': '38679388', 'username': 'gmail'}]'", "'nan'", "'Strongly Negative'", "'[0.4637781083583832, 0.3409056067466736, 0.08226823806762695, 0.032947003841400146, 0.035739779472351074]'")
# ****************************************************************************************************
# ("'1074946223667339264'", "'1074946223667339264'", "'1545122125000'", "'2018-12-18'", "'14:05:25'", "'India Standard Time'", "'2325752540'", "'apoorvaraj96'", "'Apoorva Raj'", "'nan'", "'@didbijckidas I am an employee at @ParallelDots an AI-based startup from India. I love your blog posts (especially the one titled- Top ways to improve WordPress website SEO) on wideinfo and would love to connect over email regarding guest posting contribution.'", "'['didbijckidas', 'paralleldots']'", "'[]'", "'[]'", "'0'", "'1'", "'3'", "'[]'", "'[]'", "'https://twitter.com/apoorvaraj96/status/1074946223667339264'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2325752540', 'username': 'apoorvaraj96'}, {'user_id': '1322152932', 'username': 'didbijckidas'}, {'user_id': '2244217100', 'username': 'ParallelDots'}]'", "'nan'", "'Strongly Negative'", "'[0.6969703435897827, 0.13519278168678284, 0.05473414063453674, 0.021704405546188354, 0.03271165490150452]'")
# ****************************************************************************************************
# ("'1069351007543615488'", "'1069351007543615488'", "'1543788122000'", "'2018-12-03'", "'03:32:02'", "'India Standard Time'", "'2277767923'", "'thinbrownboy'", "'Rohan Swamy'", "'nan'", "'An Post, Royal Mail, India Post, USPS, Correos, Poste Italiane and all other postal services across the globe, this is why I love you guys.\n\nAnd also why I’ll always write letters.❤️  https://www.bbc.co.uk/news/uk-scotland-edinburgh-east-fife-46386387\xa0…'", "'[]'", "'['https://www.bbc.co.uk/news/uk-scotland-edinburgh-east-fife-46386387']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/thinbrownboy/status/1069351007543615488'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2277767923', 'username': 'thinbrownboy'}]'", "'nan'", "'Strongly Negative'", "'[0.7772111892700195, 0.17064246535301208, 0.030504882335662842, 0.0105990469455719, 0.010362237691879272]'")
# ****************************************************************************************************
# ("'1068561763166289920'", "'1068561763166289920'", "'1543599951000'", "'2018-11-30'", "'23:15:51'", "'India Standard Time'", "'1010500857585168385'", "'cowquiet'", "'Quiet Cow'", "'nan'", "'I love all of my Indian colleagues.  Imagine, however, if the $30k they are paid yearly was a 6 figure salary paid instead to a readily available American tech worker, your neighbor perhaps. \n\nBonus: They don't mail the money back home to India.\n\nEND H1B TECH'", "'[]'", "'[]'", "'[]'", "'1'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/CowQuiet/status/1068561763166289920'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1010500857585168385', 'username': 'CowQuiet'}]'", "'nan'", "'Weekly Negative'", "'[0.2072935700416565, 0.4769987463951111, 0.16694828867912292, 0.03197351098060608, 0.005820870399475098]'")
# ****************************************************************************************************
# ("'1064836524116570112'", "'1064836524116570112'", "'1542711785000'", "'2018-11-20'", "'16:33:05'", "'India Standard Time'", "'869639209623068673'", "'rainesquesc'", "'🌹'", "'nan'", "'You India people I love you all for how you are progressing with the call thing.\nKaash Email mein bhi aisa entertainment milta.😂😂\nGreat Going!\n#EndIshqbaaazWithNakuulSurbhi\n#NoIshqbaaazWithoutSurbhi'", "'[]'", "'[]'", "'[]'", "'0'", "'3'", "'0'", "'['#endishqbaaazwithnakuulsurbhi', '#noishqbaaazwithoutsurbhi']'", "'[]'", "'https://twitter.com/rainesquesc/status/1064836524116570112'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '869639209623068673', 'username': 'rainesquesc'}]'", "'nan'", "'Strongly Positive'", "'[0.007182568311691284, 0.02024179697036743, 0.02764752507209778, 0.12463444471359253, 0.8300860524177551]'")
# ****************************************************************************************************
# ("'1058006890880237568'", "'1058006890880237568'", "'1541083474000'", "'2018-11-01'", "'20:14:34'", "'India Standard Time'", "'900381912383893504'", "'anshabhi1987'", "'Abhishek Srivastava'", "'nan'", "'Hurrah i answered the question hope I'll be shortlisted for price...\nEmail: abhisrivastava1987@hotmail.com\nI_Love_Amazon_India\n#AmazonSpinandWin\n@amazonIN pic.twitter.com/NOdM4PnJL1'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq7LpFsVsAAKKhg.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin']'", "'[]'", "'https://twitter.com/anshabhi1987/status/1058006890880237568'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '900381912383893504', 'username': 'anshabhi1987'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.11021789908409119, 0.2441607415676117, 0.4225594699382782, 0.16414502263069153, 0.034257352352142334]'")
# ****************************************************************************************************
# ("'1057998490167439360'", "'1057998490167439360'", "'1541081471000'", "'2018-11-01'", "'19:41:11'", "'India Standard Time'", "'2576660235'", "'kumarujjawal292'", "'UJJAWAL KUMAR'", "'nan'", "'Hope I'll be shortlisted for price...\nEmail: kumarujjawal292@gmail.com\nI_Love_Amazon_India\n#AmazonSpinandWin\n@amazonIN pic.twitter.com/YcG5GP0hpF'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq7D_-GW4AAdKPT.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin']'", "'[]'", "'https://twitter.com/kumarujjawal292/status/1057998490167439360'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2576660235', 'username': 'kumarujjawal292'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Strongly Negative'", "'[0.39598318934440613, 0.3461776375770569, 0.22377091646194458, 0.04579856991767883, 0.021309494972229004]'")
# ****************************************************************************************************
# ("'1057962730316091392'", "'1057962730316091392'", "'1541072945000'", "'2018-11-01'", "'17:19:05'", "'India Standard Time'", "'966574143520100352'", "'mohanjeet0508'", "'Mohanjeet Singh'", "'nan'", "'Hurrah i answered the question hope I'll be shortlisted for price...\nEmail: mohanjeets310@gmail.com\nI_Love_Amazon_India  pic.twitter.com/WgtXcuxhE0'", "'[]'", "'[]'", "'['https://pbs.twimg.com/media/Dq6jZOsWwAAyy1e.jpg']'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/Mohanjeet0508/status/1057962730316091392'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '966574143520100352', 'username': 'Mohanjeet0508'}]'", "'nan'", "'Neutral'", "'[0.09982743859291077, 0.23147007822990417, 0.4195025861263275, 0.17448243498802185, 0.03816568851470947]'")
# ****************************************************************************************************
# ("'1057920479225364480'", "'1057920479225364480'", "'1541062872000'", "'2018-11-01'", "'14:31:12'", "'India Standard Time'", "'876078837100036096'", "'electrontattoos'", "'Electron Tattoo Studio'", "'nan'", "'😍😍😍😍 i answered the question hope I'll be shortlisted for price...\nEmail: dipeshvadher@hotmail.com\nI_Love_Amazon_India😋😍😍😍\n#AmazonSpinandWin\n@amazonIN  https://twitter.com/junaid_4_you/status/1054677016908226560/photo/1 pic.twitter.com/52xpb1kcrX\xa0 pic.twitter.com/V71FHtZftT'", "'['amazonin']'", "'['https://twitter.com/junaid_4_you/status/1054677016908226560/photo/1']'", "'['https://pbs.twimg.com/media/Dq59DueXgAUCVwT.jpg']'", "'0'", "'0'", "'1'", "'['#amazonspinandwin']'", "'[]'", "'https://twitter.com/electrontattoos/status/1057920479225364480'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '876078837100036096', 'username': 'electrontattoos'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.10782650113105774, 0.2629075050354004, 0.44705718755722046, 0.13469198346138, 0.02764853835105896]'")
# ****************************************************************************************************
# ("'1057616589313327104'", "'1057616589313327104'", "'1540990419000'", "'2018-10-31'", "'18:23:39'", "'India Standard Time'", "'771721486339977216'", "'_kpstudio'", "'KP STUDIO'", "'nan'", "'#AmazonSpinandWin\nHurrah i answered the question hope I'll be shortlisted for price...\nEmail:prajapatikishan291@gmail.com\nI_Love_Amazon_India\n#AmazonSpinandWin\n@amazonIN pic.twitter.com/se6LOEqn95'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq1orFFVsAAfeuj.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin', '#amazonspinandwin']'", "'[]'", "'https://twitter.com/_kpstudio/status/1057616589313327104'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '771721486339977216', 'username': '_kpstudio'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.11021789908409119, 0.2441607415676117, 0.4225594699382782, 0.16414502263069153, 0.034257352352142334]'")
# ****************************************************************************************************
# ("'1057600402059755520'", "'1057600402059755520'", "'1540986559000'", "'2018-10-31'", "'17:19:19'", "'India Standard Time'", "'1057502381938823168'", "'agrawalnavratn'", "'Dr. Navratn Agrawal'", "'nan'", "'#OnePlus6TAmazonQuiz\n#oneplus6T amazon quiz \nHurrah i answered the question hope I'll be shortlisted for price...\nEmail: navratnagrawal91@gmail.com\nPhone number +917023580011\nI_Love_Amazon_India\n#oneplus6T amazon quiz\n#QuizTimeMorningsWithAmazon morning with amazon\n@amazonIN pic.twitter.com/mQsjF9qO01'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq1Z8joVAAAlLEi.jpg']'", "'0'", "'0'", "'0'", "'['#oneplus6tamazonquiz', '#oneplus6t', '#oneplus6t', '#quiztimemorningswithamazon']'", "'[]'", "'https://twitter.com/AgrawalNavratn/status/1057600402059755520'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1057502381938823168', 'username': 'AgrawalNavratn'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.1677207350730896, 0.14837059378623962, 0.21433940529823303, 0.18109622597694397, 0.21429643034934998]'")
# ****************************************************************************************************
# ("'1057599006753271809'", "'1057599006753271809'", "'1540986227000'", "'2018-10-31'", "'17:13:47'", "'India Standard Time'", "'1057596632710008833'", "'meenadeviagraw1'", "'Meena Devi Agrawal'", "'nan'", "'#OnePlus6TAmazonQuiz\n#oneplus6T amazon quiz \nHurrah i answered the question hope I'll be shortlisted for price...\nEmail: navy7737634523@gmail.com\nI_Love_Amazon_India\n#QuizTimeMorningsWithAmazon morning with amazon\n@amazonIN pic.twitter.com/MydB4W4OXx'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq1YrasU4AIuDBB.jpg']'", "'0'", "'0'", "'1'", "'['#oneplus6tamazonquiz', '#oneplus6t', '#quiztimemorningswithamazon']'", "'[]'", "'https://twitter.com/MeenaDeviAgraw1/status/1057599006753271809'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1057596632710008833', 'username': 'MeenaDeviAgraw1'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.10945600271224976, 0.1618732213973999, 0.2950189709663391, 0.21201929450035095, 0.13788357377052307]'")
# ****************************************************************************************************
# ("'1057597521202077697'", "'1057597521202077697'", "'1540985872000'", "'2018-10-31'", "'17:07:52'", "'India Standard Time'", "'1057596632710008833'", "'meenadeviagraw1'", "'Meena Devi Agrawal'", "'nan'", "'Hurrah i answered the question hope I'll be shortlisted for price...\nEmail: navy7737634523@gmail.com\n+917737634523\nI_Love_Amazon_India\n#AmazonSpinandWin\n@amazonIN pic.twitter.com/zW1FtELI3m'", "'['amazonin']'", "'[]'", "'['https://pbs.twimg.com/media/Dq1XVHXVYAAsM_Q.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin']'", "'[]'", "'https://twitter.com/MeenaDeviAgraw1/status/1057597521202077697'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1057596632710008833', 'username': 'MeenaDeviAgraw1'}, {'user_id': '1282946089', 'username': 'amazonIN'}]'", "'nan'", "'Neutral'", "'[0.11021789908409119, 0.2441607415676117, 0.4225594699382782, 0.16414502263069153, 0.034257352352142334]'")
# ****************************************************************************************************
# ("'1057592171581206528'", "'1057592171581206528'", "'1540984597000'", "'2018-10-31'", "'16:46:37'", "'India Standard Time'", "'1057502381938823168'", "'agrawalnavratn'", "'Dr. Navratn Agrawal'", "'nan'", "'#AmazonSpinandWin\nHurrah i answered the question hope I'll be shortlisted for price...\nEmail: navratnagrawal91@gmail.com\n#I_Love_Amazon_India\n+917023580011\n#AmazonSpinandWin pic.twitter.com/vsB9NoeyYS'", "'[]'", "'[]'", "'['https://pbs.twimg.com/media/Dq1SdzGUwAIYJV3.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin', '#i_love_amazon_india', '#amazonspinandwin']'", "'[]'", "'https://twitter.com/AgrawalNavratn/status/1057592171581206528'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1057502381938823168', 'username': 'AgrawalNavratn'}]'", "'nan'", "'Neutral'", "'[0.11021789908409119, 0.2441607415676117, 0.4225594699382782, 0.16414502263069153, 0.034257352352142334]'")
# ****************************************************************************************************
# ("'1054795916253650944'", "'1054795916253650944'", "'1540317918000'", "'2018-10-23'", "'23:35:18'", "'India Standard Time'", "'989539718407782400'", "'ankuragg08'", "'Ankur Himmatramka'", "'nan'", "'Huhuuu I answered the question hope I'll be shortlisted for price...\nEmail: ankuragg08@gmail.com\nI_Love_Amazon_India\n#AmazonSpinandWin\n@AmazonINoffers pic.twitter.com/bltv7uvguM'", "'['amazoninoffers']'", "'[]'", "'['https://pbs.twimg.com/media/DqNjSHhXgAAdJDe.jpg']'", "'0'", "'0'", "'0'", "'['#amazonspinandwin']'", "'[]'", "'https://twitter.com/Ankuragg08/status/1054795916253650944'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '989539718407782400', 'username': 'Ankuragg08'}, {'user_id': '3000737414', 'username': 'AmazonINoffers'}]'", "'nan'", "'Neutral'", "'[0.12496501207351685, 0.2730746269226074, 0.4232606887817383, 0.1336817741394043, 0.023470044136047363]'")
# ****************************************************************************************************
# ("'1054678752855175168'", "'1054674091171434511'", "'1540289984000'", "'2018-10-23'", "'15:49:44'", "'India Standard Time'", "'1012399367616004096'", "'aryank__'", "'Aryan khan'", "'nan'", "'Bro ur awesome I love ur videos i want blue colour apple iphone it's really awesome I love that colour.\nBro I ws from India \nIt's my email id:aaryan8587@gmail.com \nI am wishing that I could win the phone because it's awesome in India it's too costly'", "'['mkbhd']'", "'[]'", "'[]'", "'0'", "'0'", "'1'", "'[]'", "'[]'", "'https://twitter.com/Aryank__/status/1054678752855175168'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1012399367616004096', 'username': 'Aryank__'}, {'user_id': '29873662', 'username': 'MKBHD'}]'", "'nan'", "'Strongly Positive'", "'[0.023399800062179565, 0.018009066581726074, 0.03804594278335571, 0.1663757860660553, 0.8179399371147156]'")
# ****************************************************************************************************
# ("'1053148297072791560'", "'1052982437670731778'", "'1539925095000'", "'2018-10-19'", "'10:28:15'", "'India Standard Time'", "'75213976'", "'japjitravel'", "'Japji Travel'", "'nan'", "'Hey Lacey London, Good morning. I love writing and reading books so when I saw your tweet thought to get it and read it but I did not get B'coz it's not available in India. \n Please let me know why? \n\nIf you can send me its PDF formate kindly mail at vedvikas778@gmail.com'", "'['thelaceylondon']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/japjitravel/status/1053148297072791560'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '75213976', 'username': 'japjitravel'}, {'user_id': '2869103344', 'username': 'thelaceylondon'}]'", "'nan'", "'Neutral'", "'[0.17382404208183289, 0.2107318937778473, 0.25746089220046997, 0.16128486394882202, 0.19046622514724731]'")
# ****************************************************************************************************
# ("'1051739731824799744'", "'1051739731824799744'", "'1539589267000'", "'2018-10-15'", "'13:11:07'", "'India Standard Time'", "'80348490'", "'reenasatin'", "'Reena Satin'", "'nan'", '\'When in India people say "I love you" or "kisses" or makes a heart sign while parting, i always worry that these remarks, that mean "good bye", might be taken as flirting.\nWe (most of us) are this conservative.\nThis email doesn\'t give him the right to sexually abuse someone.  https://twitter.com/chetan_bhagat/status/1051691435848687616\xa0…\'', "'[]'", "'['https://twitter.com/chetan_bhagat/status/1051691435848687616']'", "'[]'", "'0'", "'0'", "'1'", "'[]'", "'[]'", "'https://twitter.com/ReenaSatin/status/1051739731824799744'", "'False'", "'https://twitter.com/chetan_bhagat/status/1051691435848687616'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '80348490', 'username': 'ReenaSatin'}]'", "'nan'", "'Strongly Positive'", "'[0.009148508310317993, 0.015821248292922974, 0.04685261845588684, 0.2046850621700287, 0.7499754428863525]'")
# ****************************************************************************************************
# ("'1049250432285962240'", "'1049250432285962240'", "'1538995771000'", "'2018-10-08'", "'16:19:31'", "'India Standard Time'", "'1049248766396518400'", "'arinmishra11'", "'arin mishra'", "'nan'", "'@taylorswift13 I am Shruti Mishra i am 13 years from India.I am really a big fan of you.I love you please come to India. I am waiting for you ......😍😍😍😍i could also send you an fan email but i dont know😃😃😃😃😃😃😃😃😃😃😃'", "'['taylorswift13']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/arinmishra11/status/1049250432285962240'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1049248766396518400', 'username': 'arinmishra11'}, {'user_id': '17919972', 'username': 'taylorswift13'}]'", "'nan'", "'Strongly Positive'", "'[0.18771645426750183, 0.2143940031528473, 0.15283620357513428, 0.08961528539657593, 0.2697414755821228]'")
# ****************************************************************************************************
# ("'1048106128570273792'", "'762143802672820224'", "'1538722948000'", "'2018-10-05'", "'12:32:28'", "'India Standard Time'", "'1013765285793366018'", "'sprinklr_india'", "'Sprinklr India'", "'nan'", "'@HDFC_Bank is slowing and steadily becoming my best friend💸\nI love personalized notes in my @gmail box especially the #WorldHeartDay one. Thanks for caring, team❤️ -Jennifer pic.twitter.com/SwKGODlinC'", "'['hdfc_bank', 'ashish_mo', 'mastercardap', 'gmail']'", "'[]'", "'['https://pbs.twimg.com/media/Doue9-gV4AEVl0K.jpg']'", "'0'", "'0'", "'0'", "'['#worldheartday']'", "'[]'", "'https://twitter.com/Sprinklr_India/status/1048106128570273792'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1013765285793366018', 'username': 'Sprinklr_India'}, {'user_id': '183230213', 'username': 'HDFC_Bank'}, {'user_id': '81765465', 'username': 'ashish_mo'}, {'user_id': '2597881976', 'username': 'MastercardAP'}, {'user_id': '38679388', 'username': 'gmail'}]'", "'nan'", "'Strongly Positive'", "'[0.006179928779602051, 0.010231375694274902, 0.020660698413848877, 0.11691421270370483, 0.8540645837783813]'")
# ****************************************************************************************************
# ("'1048091348773949440'", "'1047843528401809408'", "'1538719424000'", "'2018-10-05'", "'11:33:44'", "'India Standard Time'", "'300678124'", "'pavankumar102'", "'pavan kumar'", "'nan'", "'ios and android app working welldone good \ni love google services \nandroid 1 release date when in india'", "'['gmail']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/pavankumar102/status/1048091348773949440'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '300678124', 'username': 'pavankumar102'}, {'user_id': '38679388', 'username': 'gmail'}]'", "'nan'", "'Strongly Positive'", "'[0.03452014923095703, 0.08229896426200867, 0.10917669534683228, 0.2548946142196655, 0.3914584517478943]'")
# ****************************************************************************************************
# ("'1046700292685754368'", "'1045908552689340416'", "'1538387771000'", "'2018-10-01'", "'15:26:11'", "'India Standard Time'", "'37785792'", "'dairnewoods'", "'Dairne Woods'", "'nan'", "'I love the idea of a good old penpal, and snail mail friendship. I miss the art of a hand written letter. I did give it a go - one in Sweden and one in India, but they never wrote back. So good old emails it is! 🤣'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/DairneWoods/status/1046700292685754368'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '37785792', 'username': 'DairneWoods'}]'", "'nan'", "'Strongly Negative'", "'[0.574130117893219, 0.29255473613739014, 0.06590285897254944, 0.02440166473388672, 0.006234884262084961]'")
# ****************************************************************************************************
# ("'1046271763519135744'", "'1046271763519135744'", "'1538285601000'", "'2018-09-30'", "'11:03:21'", "'India Standard Time'", "'869430469'", "'manpowermill'", "'Millennium Manpower '", "'nan'", "'I love  to meet u mail me will be shortly in india smarrikar61@gmail.com  https://twitter.com/tamilkalavi3/status/1044494519436173314\xa0…'", "'[]'", "'['https://twitter.com/tamilkalavi3/status/1044494519436173314']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/ManpowerMill/status/1046271763519135744'", "'False'", "'https://twitter.com/tamilkalavi3/status/1044494519436173314'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '869430469', 'username': 'ManpowerMill'}]'", "'nan'", "'Strongly Positive'", "'[0.1143808662891388, 0.21191582083702087, 0.18329793214797974, 0.18203145265579224, 0.28266626596450806]'")
# ****************************************************************************************************
# ("'1045768944257183744'", "'1045765871053017088'", "'1538165720000'", "'2018-09-29'", "'01:45:20'", "'India Standard Time'", "'847494481184145409'", "'calumder'", "'DISHA LOVES COOL GUY CAL🍑🤘🏻'", "'nan'", "'I love you. I was actually gonna tweet from my main but I tweeted from the 5sos India Wala acc. But all I want to say I hope he actually do read your email. Koi bhi chalega Indian fam mein se'", "'['ashton5sos', '5sos']'", "'[]'", "'[]'", "'2'", "'0'", "'1'", "'[]'", "'[]'", "'https://twitter.com/calumder/status/1045768944257183744'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '847494481184145409', 'username': 'calumder'}, {'user_id': '439125710', 'username': 'Ashton5SOS'}, {'user_id': '264107729', 'username': '5SOS'}]'", "'nan'", "'Weekly Negative'", "'[0.1567515730857849, 0.2415454387664795, 0.2048741579055786, 0.12195515632629395, 0.17339962720870972]'")
# ****************************************************************************************************
# ("'1044905776626589696'", "'1044905776626589696'", "'1537959925000'", "'2018-09-26'", "'16:35:25'", "'India Standard Time'", "'2269234344'", "'adityabohare'", "'aditya bohare'", "'nan'", "'@KP24 hello i am Aditya from india and i am big fan of your work bcz i am same as you i love very much to all animals its my passion so i want to work with you in all work and save these beautiful lovable animals i also mail u but no reply plz sir give chance to work with you .'", "'['kp24']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/AdityaBohare/status/1044905776626589696'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2269234344', 'username': 'AdityaBohare'}, {'user_id': '171117515', 'username': 'KP24'}]'", "'nan'", "'Strongly Positive'", "'[0.05208355188369751, 0.08070608973503113, 0.08725899457931519, 0.30940473079681396, 0.5302398800849915]'")
# ****************************************************************************************************
# ("'1044128591900860418'", "'1044128591900860418'", "'1537774629000'", "'2018-09-24'", "'13:07:09'", "'India Standard Time'", "'460090961'", "'imdivyanand'", "'Divyanand Kumar'", "'nan'", "'Not going OFF AIR \nConfirmed by Star India's MAIL to me.\nFeeling relaxed & happy for now.\n@NakuulMehta\n@SurbhiChandna\n#Ishqbaaaz has been my life & I can't imagine my life without #Shivika.\nThis is my beautiful world.\nI love ur SOUL Surbhi. Love u forever and ever.\n@StarPlus pic.twitter.com/Cnivoha1rj'", "'['nakuulmehta', 'surbhichandna', 'starplus']'", "'[]'", "'['https://pbs.twimg.com/media/Dn19Z2TVAAE7Bms.jpg']'", "'1'", "'2'", "'5'", "'['#ishqbaaaz', '#shivika']'", "'[]'", "'https://twitter.com/imdivyanand/status/1044128591900860418'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '460090961', 'username': 'imdivyanand'}, {'user_id': '52351621', 'username': 'NakuulMehta'}, {'user_id': '33242346', 'username': 'SurbhiChandna'}, {'user_id': '93825359', 'username': 'StarPlus'}]'", "'nan'", "'Strongly Positive'", "'[0.009758800268173218, 0.010844647884368896, 0.02105996012687683, 0.12487661838531494, 0.858999490737915]'")
# ****************************************************************************************************
# ("'1041927063194796032'", "'1041915184791605248'", "'1537249744000'", "'2018-09-18'", "'11:19:04'", "'India Standard Time'", "'328977661'", "'rajeshkumarsao'", "'Rajesh Kumar Sao'", "'nan'", "'ache din service - After connecting twice thrice now they are asking send email and request to expedite the process. I love my India.'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/RajeshKumarSao/status/1041927063194796032'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '328977661', 'username': 'RajeshKumarSao'}]'", "'nan'", "'Strongly Negative'", "'[0.2656513452529907, 0.16461309790611267, 0.08547639846801758, 0.09146502614021301, 0.24322804808616638]'")
# ****************************************************************************************************
# ("'1041130860823629825'", "'1041130860823629825'", "'1537059915000'", "'2018-09-16'", "'06:35:15'", "'India Standard Time'", "'3012852364'", "'pashgotbandz'", "'Hunnitgram PashBando'", "'nan'", "'I’m so ready to mail  off India’s pics to family/friends!!! I love being a mommy ❤️'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/pashgotbandz/status/1041130860823629825'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '3012852364', 'username': 'pashgotbandz'}]'", "'nan'", "'Strongly Positive'", "'[0.10336911678314209, 0.10334140062332153, 0.11972913146018982, 0.19117209315299988, 0.40613654255867004]'")
# ****************************************************************************************************
# ("'1039194784626176000'", "'1039194784626176000'", "'1536598318000'", "'2018-09-10'", "'22:21:58'", "'India Standard Time'", "'151803550'", "'tuhinat221b'", "'Tuhin Das'", "'nan'", "'@RaphaelBW hey there from India. I love BoJack and it is one of my favourite shows. I also run a small blog on cinema and TV. I would love to ask you some questions about the old and new season of the show for the blog via DM or email. It would be an honour if you agree.'", "'['raphaelbw']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/tuhinat221b/status/1039194784626176000'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '151803550', 'username': 'tuhinat221b'}, {'user_id': '61688899', 'username': 'RaphaelBW'}]'", "'nan'", "'Strongly Positive'", "'[0.048900097608566284, 0.10136452317237854, 0.15325802564620972, 0.28086674213409424, 0.42672669887542725]'")
# ****************************************************************************************************
# ("'1034033516051353602'", "'1034032678545383424'", "'1535367776000'", "'2018-08-27'", "'16:32:56'", "'India Standard Time'", "'856301919681236992'", "'paco1973234'", "'Pascal Eicher'", "'nan'", "'Hello Lana,firstable thx you for what you did and will do with India.I love your energy!maybe you can help me,I’m trying to reach Saygin since months but the email I have doesn’t work.Could you give me his email or tell him to join me. I have document for him. Eicherp@hotmail.com'", "'['lanarose786']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/Paco1973234/status/1034033516051353602'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '856301919681236992', 'username': 'Paco1973234'}, {'user_id': '2188669561', 'username': 'LanaRose786'}]'", "'nan'", "'Strongly Negative'", "'[0.3696030378341675, 0.25748512148857117, 0.16895997524261475, 0.09143808484077454, 0.09194928407669067]'")
# ****************************************************************************************************
# ("'1029425220703145984'", "'1029425220703145984'", "'1534269073000'", "'2018-08-14'", "'23:21:13'", "'India Standard Time'", "'110257712'", "'fdmhome'", "'Fidelity Direct Mortgage'", "'nan'", '\'India Pope: "Mily is one of the very few processor I can say I love to work with, with my main reason being I can reach her via email or phone call at almost any time. Milly Hernandez Fleitas and Jose Burgos to me are...  https://www.facebook.com/fdmhome/posts/1782170288568895\xa0…\'', "'[]'", "'['https://www.facebook.com/fdmhome/posts/1782170288568895']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/fdmhome/status/1029425220703145984'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '110257712', 'username': 'fdmhome'}]'", "'nan'", "'Strongly Positive'", "'[0.14813682436943054, 0.10514208674430847, 0.0774538516998291, 0.09403631091117859, 0.6582791805267334]'")
# ****************************************************************************************************
# ("'1028301428983582721'", "'1028301428983582721'", "'1534001140000'", "'2018-08-11'", "'20:55:40'", "'India Standard Time'", "'15705567'", "'rafat'", "'Rafat Ali, Media Operator'", "'nan'", '\'I know you don\'t mean any ill will, but if the first thing you say after meeting me for the first time is "I love Indian food!" or "I loved India when I went there!" or "Salaam" or send me an email with "Namaste" as the greeting, you are, well, assuming a lot of things....\'', "'[]'", "'[]'", "'[]'", "'9'", "'6'", "'61'", "'[]'", "'[]'", "'https://twitter.com/rafat/status/1028301428983582721'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '15705567', 'username': 'rafat'}]'", "'nan'", "'Strongly Negative'", "'[0.6120694279670715, 0.2504509389400482, 0.08611100912094116, 0.03453657031059265, 0.02755323052406311]'")
# ****************************************************************************************************
# ("'1027985017824149504'", "'1027985017824149504'", "'1533925701000'", "'2018-08-10'", "'23:58:21'", "'India Standard Time'", "'2222105617'", "'tariq_wanii'", "'Tariq Wani'", "'nan'", "'@DrummerBoy2112\n\nHello sir! Glad to see that you are teaching chemistry. Sir I'm from Kashmir India. I love to teach as well as read chemistry or even I love to interact with new senior chemistry teaching persons. I would like to interact with you. Mail me itstariq08@gmail.com'", "'['drummerboy2112']'", "'[]'", "'[]'", "'0'", "'0'", "'1'", "'[]'", "'[]'", "'https://twitter.com/Tariq_wanii/status/1027985017824149504'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2222105617', 'username': 'Tariq_wanii'}, {'user_id': '405088825', 'username': 'DrummerBoy2112'}]'", "'nan'", "'Strongly Positive'", "'[0.0920586884021759, 0.058019936084747314, 0.09475123882293701, 0.2132275104522705, 0.6275227665901184]'")
# ****************************************************************************************************
# ("'1027788668340236289'", "'1027786663634890757'", "'1533878888000'", "'2018-08-10'", "'10:58:08'", "'India Standard Time'", "'1022010414249467906'", "'deepakj10932740'", "'Deepak Jain'", "'nan'", "'I want one chance to work for india with you sir..how honest and dedictae i work..i will show u....i love and made for india and famiky\nEmail id  deepsjain@hotmail.com'", "'['pmoindia']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/DeepakJ10932740/status/1027788668340236289'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1022010414249467906', 'username': 'DeepakJ10932740'}, {'user_id': '471741741', 'username': 'PMOIndia'}]'", "'nan'", "'Strongly Negative'", "'[0.5311938524246216, 0.23458918929100037, 0.1029449999332428, 0.05155026912689209, 0.08149582147598267]'")
# ****************************************************************************************************
# ("'1027492098352848896'", "'1027492098352848896'", "'1533808180000'", "'2018-08-09'", "'15:19:40'", "'India Standard Time'", "'771308810270937090'", "'madhurima__ray'", "'Madhurima Ray'", "'nan'", "' http://www.madhurimaray.com/\xa0\nMail - modelmadhurima@gmail.com\n\nI am based as an Independent Escort in Mumbai and available for Out call appointments. I love to Travel and can visit throughout India. I have remained close to my culture and language too.'", "'[]'", "'['http://www.madhurimaray.com/']'", "'[]'", "'0'", "'0'", "'4'", "'[]'", "'[]'", "'https://twitter.com/madhurima__ray/status/1027492098352848896'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '771308810270937090', 'username': 'madhurima__ray'}]'", "'nan'", "'Strongly Positive'", "'[0.0837341845035553, 0.07364526391029358, 0.07147330045700073, 0.15702161192893982, 0.5638113021850586]'")
# ****************************************************************************************************
# ("'1024934909373243392'", "'1024934909373243392'", "'1533198499000'", "'2018-08-02'", "'13:58:19'", "'India Standard Time'", "'2381809525'", "'rsreerajrnair7'", "'sreeraj r nair'", "'nan'", "'Cristiano Ronaldo (Portugal) - Jersey Number 7 - CR7\nAntoine Griezmann (France)  - Jersey Number 7 - AG7\nSreeraj R. Nair  (India) -  email id -  sreerajrnair7@gmai.com - SR7\n    I Love CR7, I Love AG7 and I Love number 7'", "'[]'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/RSreerajrnair7/status/1024934909373243392'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2381809525', 'username': 'RSreerajrnair7'}]'", "'nan'", "'Strongly Positive'", "'[0.0494350790977478, 0.038850635290145874, 0.03403368592262268, 0.05227220058441162, 0.7513883709907532]'")
# ****************************************************************************************************
# ("'1022154825591607296'", "'1022144325025710081'", "'1532535675000'", "'2018-07-25'", "'21:51:15'", "'India Standard Time'", "'1596616200'", "'mukhtiar_gmail'", "'Mukhtiar'", "'nan'", "'People of KPK remembers very well the blasts of 2008-13 and their masterminds, Thats why I love India against Kashmir and Israel against Palestine.'", "'['hurrzaidi', 'xadeejournalist', 'iusmanaliii']'", "'[]'", "'[]'", "'1'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/mukhtiar_gmail/status/1022154825591607296'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1596616200', 'username': 'mukhtiar_gmail'}, {'user_id': '225786766', 'username': 'hurrzaidi'}, {'user_id': '286613468', 'username': 'Xadeejournalist'}, {'user_id': '1587141607', 'username': 'iUsmanaliii'}]'", "'nan'", "'Strongly Positive'", "'[0.0409853458404541, 0.08963340520858765, 0.09967461228370667, 0.1567516326904297, 0.5785605907440186]'")
# ****************************************************************************************************
# ...
# ****************************************************************************************************
# ("'723032028719943681'", "'723032028719943681'", "'1461219243000'", "'2016-04-21'", "'11:44:03'", "'India Standard Time'", "'3956986212'", "'mail_jimmy89'", "'jassi singh'", "'nan'", "'Once faced with exodus, SpiceJet now attracts talent from rivals: Looking at airline's turnaround story, ex-st...  http://bit.ly/1VlMGVk\xa0'", "'[]'", "'['http://bit.ly/1VlMGVk']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/mail_jimmy89/status/723032028719943681'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '3956986212', 'username': 'mail_jimmy89'}]'", "'nan'", "'Neutral'", "'[0.06289839744567871, 0.2148737609386444, 0.36554044485092163, 0.23205691576004028, 0.03191244602203369]'")
# ****************************************************************************************************
# ("'715914630296690690'", "'715914630296690690'", "'1459522323000'", "'2016-04-01'", "'20:22:03'", "'India Standard Time'", "'57273159'", "'shivamsarin'", "'Shivam Sarin'", "'nan'", "'@TheSanjivKapoor Hello Sir, I'm having an issue with SpiceJet airline. I was hoping can you help me with the email of Mr Ajay Singh CEO SJ'", "'['thesanjivkapoor']'", "'[]'", "'[]'", "'1'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/shivamsarin/status/715914630296690690'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '57273159', 'username': 'shivamsarin'}, {'user_id': '2275714236', 'username': 'TheSanjivKapoor'}]'", "'nan'", "'Strongly Negative'", "'[0.4630167484283447, 0.41348108649253845, 0.14890459179878235, 0.02894565463066101, 0.008579671382904053]'")
# ****************************************************************************************************
# ("'704562857971621888'", "'704562857971621888'", "'1456815850000'", "'2016-03-01'", "'12:34:10'", "'India Standard Time'", "'3956986212'", "'mail_jimmy89'", "'jassi singh'", "'nan'", "'Former SpiceJet executive Sanjiv Kapoor joins Vistara: He is joining the airlines as Chief Strategy and Commer...  http://bit.ly/1neQclc\xa0'", "'[]'", "'['http://bit.ly/1neQclc']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/mail_jimmy89/status/704562857971621888'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '3956986212', 'username': 'mail_jimmy89'}]'", "'nan'", "'Weekly Positive'", "'[0.033847540616989136, 0.14796271920204163, 0.3122212588787079, 0.32525742053985596, 0.059303849935531616]'")
# ****************************************************************************************************
# ("'579943440013656065'", "'579942146410594305'", "'1427104265000'", "'2015-03-23'", "'15:21:05'", "'India Standard Time'", "'2475549384'", "'am_dilip'", "'dilip'", "'nan'", "'@mail_today @IndiaToday In league with Airlines Staff, had an experience: lost baggage spicejet flight'", "'['mail_today', 'indiatoday']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/Am_dilip/status/579943440013656065'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2475549384', 'username': 'Am_dilip'}, {'user_id': '2904188772', 'username': 'mail_today'}, {'user_id': '19897138', 'username': 'IndiaToday'}]'", "'nan'", "'Weekly Negative'", "'[0.129169762134552, 0.4025461673736572, 0.1701321005821228, 0.09001150727272034, 0.13846340775489807]'")
# ****************************************************************************************************
# ("'565524718455775232'", "'565524718455775232'", "'1423666574000'", "'2015-02-11'", "'20:26:14'", "'India Standard Time'", "'2901604100'", "'vacationcapsule'", "'Vacation Capsule'", "'nan'", "'Best price of spicejet airline : Delhi - Dubai - Delhi @ 13000/- \n\nVacation Capsule \nTel: +91-9999993673\nEmail:...  http://fb.me/7gXxk0zhn\xa0'", "'[]'", "'['http://fb.me/7gXxk0zhn']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/VacationCapsule/status/565524718455775232'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2901604100', 'username': 'VacationCapsule'}]'", "'nan'", "'Strongly Positive'", "'[0.01755201816558838, 0.014296472072601318, 0.019768208265304565, 0.1105438768863678, 0.8180804252624512]'")
# ****************************************************************************************************
# ("'558992270267920384'", "'558985863414050817'", "'1422109117000'", "'2015-01-24'", "'19:48:37'", "'India Standard Time'", "'82950261'", "'haiyogesh'", "'yogesh'", "'nan'", "'@flyspicejet @GoibiboDotCom Mail states that they have not received the refund from the airline spicejet yet.  pic.twitter.com/bodL7jTFP4'", "'['flyspicejet']'", "'[]'", "'['https://pbs.twimg.com/media/B8HwgcKCAAEefCs.png']'", "'2'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/haiyogesh/status/558992270267920384'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '82950261', 'username': 'haiyogesh'}, {'user_id': '39214789', 'username': 'flyspicejet'}]'", "'nan'", "'Strongly Negative'", "'[0.6509462594985962, 0.19740676879882812, 0.08100467920303345, 0.02707234025001526, 0.021089136600494385]'")
# ****************************************************************************************************
# ("'541274756339613696'", "'541274756339613696'", "'1417884932000'", "'2014-12-06'", "'22:25:32'", "'India Standard Time'", "'252315428'", "'lowcost_airline'", "'Low-cost Airlines'", "'nan'", "'MY BIZ: DGCA withdraws 186 slots from troubled low-cost carrier SpiceJet - Daily Mail  http://dlvr.it/7lCv6Y\xa0'", "'[]'", "'['http://dlvr.it/7lCv6Y']'", "'[]'", "'0'", "'1'", "'0'", "'[]'", "'[]'", "'https://twitter.com/lowcost_airline/status/541274756339613696'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '252315428', 'username': 'lowcost_airline'}]'", "'nan'", "'Weekly Positive'", "'[0.0026526451110839844, 0.014658510684967041, 0.0775805115699768, 0.5010015368461609, 0.33130377531051636]'")
# ****************************************************************************************************
# ("'536071651092201472'", "'536071651092201472'", "'1416644416000'", "'2014-11-22'", "'13:50:16'", "'India Standard Time'", "'2805804097'", "'viralflowcom'", "'videoviral'", "'nan'", "'SpiceJet Airlines Customer Care Phone Number, Toll Free Helpline Number, Email\xa0ID  http://wp.me/p5eBk4-EH\xa0'", "'[]'", "'['http://wp.me/p5eBk4-EH']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/viralflowcom/status/536071651092201472'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2805804097', 'username': 'viralflowcom'}]'", "'nan'", "'Strongly Negative'", "'[0.7635104656219482, 0.11419019103050232, 0.03864496946334839, 0.021204859018325806, 0.0249461829662323]'")
# ****************************************************************************************************
# ("'536071627474501632'", "'536071627474501632'", "'1416644410000'", "'2014-11-22'", "'13:50:10'", "'India Standard Time'", "'373195484'", "'jobremind'", "'h2hhelp'", "'nan'", "'SpiceJet Airlines Customer Care Phone Number, Toll Free Helpline Number, Email ID  http://wp.me/p5eBk4-EH\xa0  http://fb.me/1osVrlEPi\xa0'", "'[]'", "'['http://wp.me/p5eBk4-EH', 'http://fb.me/1osVrlEPi']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/JOBRemind/status/536071627474501632'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '373195484', 'username': 'JOBRemind'}]'", "'nan'", "'Strongly Negative'", "'[0.7635104656219482, 0.11419019103050232, 0.03864496946334839, 0.021204859018325806, 0.0249461829662323]'")
# ****************************************************************************************************
# ("'535064778557751297'", "'535064778557751297'", "'1416404358000'", "'2014-11-19'", "'19:09:18'", "'India Standard Time'", "'101779207'", "'shraddha_v'", "'shraddha singh'", "'nan'", "'@flyspicejet Deccan chronicle article says SpiceJet makin altrnt arngmnts wid othr airlines while their nodal officer says othrwse on email'", "'['flyspicejet']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/shraddha_v/status/535064778557751297'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '101779207', 'username': 'shraddha_v'}, {'user_id': '39214789', 'username': 'flyspicejet'}]'", "'nan'", "'Strongly Positive'", "'[0.22120949625968933, 0.20043089985847473, 0.14235323667526245, 0.12321394681930542, 0.28719383478164673]'")
# ****************************************************************************************************
# ("'422683120517648384'", "'422638378476003328'", "'1389610483000'", "'2014-01-13'", "'16:24:43'", "'India Standard Time'", "'199242943'", "'jagidy'", "'JAGI YADAV'", "'nan'", "'@flyspicejet : Airline PNR : MHNDBS, Email ID : jagidy@gmail.com\n Spicejet SG 114, Dept@Mumbai, Terminal 1B (SantaCruz) 7 May 2013, 10:55am.'", "'['flyspicejet']'", "'[]'", "'[]'", "'1'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/jagidy/status/422683120517648384'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '199242943', 'username': 'jagidy'}, {'user_id': '39214789', 'username': 'flyspicejet'}]'", "'nan'", "'Weekly Negative'", "'[0.2745169997215271, 0.3627787232398987, 0.1743212342262268, 0.049698829650878906, 0.03276699781417847]'")
# ****************************************************************************************************
# ("'418320872219217921'", "'418320872219217921'", "'1388570442000'", "'2014-01-01'", "'15:30:42'", "'India Standard Time'", "'2271433814'", "'wallovens'", "'Barlow'", "'nan'", "'Airlines look for ways to heal fuel burn: SpiceJet and IndiGo did not respond to an email query on the subject...  http://binged.it/1k6S7Fn\xa0'", "'[]'", "'['http://binged.it/1k6S7Fn']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/wallovens/status/418320872219217921'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '2271433814', 'username': 'wallovens'}]'", "'nan'", "'Weekly Negative'", "'[0.21082258224487305, 0.4744223654270172, 0.1811733841896057, 0.04620400071144104, 0.04134964942932129]'")
# ****************************************************************************************************
# ("'367958024817606656'", "'367957950083514369'", "'1376563004000'", "'2013-08-15'", "'16:06:44'", "'India Standard Time'", "'39214789'", "'flyspicejet'", "'SpiceJet'", "'nan'", "'@mummandola SpiceJet Airlines @flyspicejet 14s @mummandola Please DM us your number, email id and address. We will get back to you soon. :)'", "'['flyspicejet']'", "'[]'", "'[]'", "'1'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/flyspicejet/status/367958024817606656'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '39214789', 'username': 'flyspicejet'}]'", "'nan'", "'Strongly Negative'", "'[0.2468782365322113, 0.20045968890190125, 0.11770802736282349, 0.08380332589149475, 0.21859505772590637]'")
# ****************************************************************************************************
# ("'361675363069345794'", "'361675363069345794'", "'1375065100000'", "'2013-07-29'", "'08:01:40'", "'India Standard Time'", "'1554171294'", "'airlinenewslive'", "'Airline Newswire'", "'nan'", "'BREAKING: SpiceJet in talks over stake sale to foreign airline – Daily Mail: Daily MailSpiceJet in talks over ...   http://bit.ly/153PlqY\xa0'", "'[]'", "'['http://bit.ly/153PlqY']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/AirlineNewsLive/status/361675363069345794'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '1554171294', 'username': 'AirlineNewsLive'}]'", "'nan'", "'Strongly Positive'", "'[0.10895657539367676, 0.1216076910495758, 0.1958913505077362, 0.19373562932014465, 0.22901156544685364]'")
# ****************************************************************************************************
# ("'273305040536621057'", "'273305040536621057'", "'1353995974000'", "'2012-11-27'", "'11:29:34'", "'India Standard Time'", "'811714476'", "'bacossey'", "'QT'", "'nan'", '\'AirAsia denies stake sale talks with SpiceJet: In an email, a SpiceJet spokesperson said: "A few foreign airline...  http://bit.ly/ThB410\xa0\'', "'[]'", "'['http://bit.ly/ThB410']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/Bacossey/status/273305040536621057'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '811714476', 'username': 'Bacossey'}]'", "'nan'", "'Neutral'", "'[0.10239630937576294, 0.19901010394096375, 0.37144050002098083, 0.2075759470462799, 0.033491164445877075]'")
# ****************************************************************************************************
# ("'273301565216022528'", "'273301565216022528'", "'1353995145000'", "'2012-11-27'", "'11:15:45'", "'India Standard Time'", "'20763017'", "'rediffbusiness'", "'Rediff Business'", "'nan'", '\'AirAsia denies stake sale talks with SpiceJet: In an email, a SpiceJet spokesperson said: "A few foreign airline...  http://bit.ly/10LZhml\xa0\'', "'[]'", "'['http://bit.ly/10LZhml']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/rediffbusiness/status/273301565216022528'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '20763017', 'username': 'rediffbusiness'}]'", "'nan'", "'Neutral'", "'[0.10239630937576294, 0.19901010394096375, 0.37144050002098083, 0.2075759470462799, 0.033491164445877075]'")
# ****************************************************************************************************
# ("'273299549664194560'", "'273299549664194560'", "'1353994664000'", "'2012-11-27'", "'11:07:44'", "'India Standard Time'", "'149063337'", "'realrediffcom'", "'rediff.com'", "'nan'", '\'AirAsia denies stake sale talks with SpiceJet: In an email, a SpiceJet spokesperson said: "A few foreign airline...  http://bit.ly/ThxLHi\xa0\'', "'[]'", "'['http://bit.ly/ThxLHi']'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/RealRediffCom/status/273299549664194560'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '149063337', 'username': 'RealRediffCom'}]'", "'nan'", "'Neutral'", "'[0.08977201581001282, 0.2478630244731903, 0.37110352516174316, 0.2439175248146057, 0.05626043677330017]'")
# ****************************************************************************************************
# ("'101611961527189504'", "'101544778612752385'", "'1313061154000'", "'2011-08-11'", "'16:42:34'", "'India Standard Time'", "'18273928'", "'nativesknow'", "'Ashwin Rajan'", "'nan'", '\'@janchip worse if the airline sends your confirmed e-ticket to the email id of your "next of kin". Happened to me with Spicejet - yikes!\'', "'['janchip']'", "'[]'", "'[]'", "'0'", "'0'", "'0'", "'[]'", "'[]'", "'https://twitter.com/nativesknow/status/101611961527189504'", "'False'", "'nan'", "'0'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'nan'", "'[{'user_id': '18273928', 'username': 'nativesknow'}, {'user_id': '14491008', 'username': 'janchip'}]'", "'nan'", "'Strongly Negative'", "'[0.6222770810127258, 0.28854385018348694, 0.08990791440010071, 0.01700630784034729, 0.0063246190547943115]'")
# ****************************************************************************************************

# %% [markdown]
# # 1.Scraping

# %%
def info(name):
        driver = webdriver.Chrome(executable_path='chromedriver')
        s="";
        for i in name.split():
            s+="-"+i
        import re
        try:
            driver.get("https://www.quora.com/profile/"+s[1:])
        except:
            return
        try:
            description = driver.find_element_by_class_name('UserCredential').text
        except:
            description=""
        try:
            credentials_and_highlights = driver.find_element_by_class_name('AboutSection')
        except:
            credentials_and_highlights=""
            
            
        try:
                education = credentials_and_highlights.find_element_by_class_name('SchoolCredentialListItem')
                education = re.sub(r'Studied at', '', education.find_element_by_class_name('UserCredential').text).strip()
        except:
                education = ''
        try:
                lives_in = credentials_and_highlights.find_element_by_class_name('LocationCredentialListItem')
                lives_in = re.sub(r'Lives in', '', lives_in.find_element_by_class_name('UserCredential').text).strip()
        except:
                lives_in = ''
       
        print(name)
        print(description)
        print(education)
        print(lives_in)
        
        try:
            num_answers = int(re.sub('\D', '', driver.find_element_by_class_name('AnswersNavItem').find_element_by_class_name('list_count').text))
        except:
            num_answers=0
        try:
            num_questions = int(re.sub('\D', '', driver.find_element_by_class_name('QuestionsNavItem').find_element_by_class_name('list_count').text))
        except:
            num_questions=0
        
        try:
            num_followers = int(re.sub('\D', '', driver.find_element_by_class_name('FollowersNavItem').find_element_by_class_name('list_count').text))
        except:
            num_followers=0
        try:
            num_following = int(re.sub('\D', '', driver.find_element_by_class_name('FollowingNavItem').find_element_by_class_name('list_count').text))
        except:
            num_following=0
        try:
           num_topics = int(re.sub('\D', '', driver.find_element_by_class_name('TopicsNavItem').find_element_by_class_name('list_count').text))
        except:
            num_topics=0

 
            
            
        print(name,description)
        print(num_answers,num_questions,num_followers,num_following)
        
        return name,description,education,lives_in,num_answers,num_questions,num_followers,num_following



        driver.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import csv
import pandas as pd

def scrapper_quora(sentence):
    import spacy
    import nltk
    nltk.download('averaged_perceptron_tagger')

    nlp = spacy.load('en_core_web_sm')

    import re
    l=[]
    k=[]
    d=[]
    cnt=0
    manylinks=[]
    usernames=[]

    punctuations = '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~'
    texts = []
    #for i in b:
    rev=re.sub('[^a-zA-Z]',' ',str(sentence))
    rev=rev.lower();
    doc = nlp(rev, disable=['parser', 'ner'])
    tokens = [tok.lemma_.lower().strip() for tok in doc if tok.lemma_ != '-PRON-']
    tokens = [tok for tok in tokens if tok not in nlp.Defaults.stop_words and tok not in punctuations]
    #tokens = ' '.join(tokens)
    #texts.append(tokens)
    '''
    tagged = nltk.pos_tag(tokens)
    print(tagged)
    a=[]
    for i in tagged:
        log = (i[1][0] == 'N')
        if log == True:
          a.append(i[0])
    print("this is a",a)
    '''
    sk = set(tokens)
    print("this is sk",sk)
    print(tokens)
    
    for i in sk:
        manylinks.append("https://www.quora.com/topic/"+str(i))
    
    
#     link1 = "https://www.quora.com/topic/"+keyword
#     #link2 = input("Enter second link")
#     manylinks = list()
#     manylinks.append(link1)
    #manylinks.append(link2)
    
    ques=[]
    ques_no=[]
   
    
    qusers=[]
    user_details=[]

    
    ful=[]
    ans_no=[]
    ans=[]
    ful1=[]
    count=1
    
    for olink in manylinks:
        qlinks = list()
        print(olink)
        options = webdriver.ChromeOptions()
        options.binary_location = "C:/Program Files (x86)/Google/Chrome/Application/chrome.exe"
        browser = webdriver.Chrome(executable_path=r'C:\Users\saireddyavs\Desktop\twitter bot\twitter_scrapper\chromedriver', chrome_options=options)
        try:
            browser.get(olink)
        except:
            continue
        time.sleep(1)
        elem = browser.find_element_by_tag_name("body")


        no_of_pagedowns = 50
        while no_of_pagedowns:
            elem.send_keys(Keys.PAGE_DOWN)
            time.sleep(0.2)
            no_of_pagedowns-=1
        post_elems =browser.find_elements_by_xpath("//a[@class='question_link']")
        for post in post_elems:
            qlink = post.get_attribute("href")
            print(qlink)
            qlinks.append(qlink)
        
        print(len(qlinks))

        for qlink in qlinks:

            append_status=0

            row = list()
            
            us=[]
            
            

            browser.get(qlink)
            time.sleep(1)


            elem = browser.find_element_by_tag_name("body")


            no_of_pagedowns = 1
            while no_of_pagedowns:
                elem.send_keys(Keys.PAGE_DOWN)
                time.sleep(0.2)
                no_of_pagedowns-=1


    #         #Question Names
    #         qname =browser.find_elements_by_xpath("//div[@class='question_text_edit']")
    #         for q in qname:
    #             print(q.text)
    #             row.append(q.text)
            qname =browser.find_elements_by_xpath("//div[@class='question_text_edit']")
            k1=0
            k2=0
            for q in qname:
                
                
                for i in sk:
                    if i in q.text.lower():
                        k1+=1
                        
                if k1>=len(sk)/2:
                    qq=q.text
                    ful.append([qq,qlink])
                    print(q.text)
                    
                

            all_ans=browser.find_elements_by_xpath("//div[@class='ui_qtext_expanded']")
            i=1
            answer_field = list()
            for post in all_ans:
                if True:
                    
                    
                    
                    for i in sk:
                        if i in post.text.lower():
                            k2+=1
                    if k2>=len(sk)/2:
#                         row.append(post.text)
#                         ans.append(post.text)
#                         ans_no.append("answer to question_"+str(count))
                        print("Answer : ")
                        print(post.text)

                        ful.append([post.text,qlink])
                
                        
        
                    
                    
                else:
                    break

            
            
            if k1<len(sk)/2 and k2<len(sk)/2:
                continue
            
                
            try:
                
                name=browser.find_elements_by_xpath("//a[@class='user']")
                
                for i in name:
                    print(i.text)
                    usernames.append([i.text,qlink])
                    us.append(i.text)
                    
                
               
            except:
                name=""
                print("name not came")
            
            
            
            
            
            
            


           # print(row)
            

            

            print("*"*50)
            count+=1

        browser.quit() 

    df=pd.DataFrame(ful,columns=["text","link"])
    df.to_csv("questions.csv")
#         df=pd.DataFrame(ful1,columns=['answer',"answers_number"])
#         df.to_csv("answers.csv")

        
        
        
        
    user_details=[]
    for i in usernames:
            user_details.append([info(i[0]),i[1]])
        
    users=[]
    for i in user_details:
            print(i)
            l=list(i[0])
            l.append(i[1])
            users.append(l)

    df=pd.DataFrame(users,columns=["name","description","education","lives_in","num_answers","num_questions","num_followers","num_following","link"])


    df.fillna("")

    df.to_csv("user_details.csv")

# %%
scrapper_quora(input("Enter Sentence::"))
# Out:
# Enter Sentence::spicejet airlines
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\saireddyavs\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# this is sk {'airline', 'spicejet'}
# ['spicejet', 'airline']
# https://www.quora.com/topic/airline
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\ipykernel_launcher.py:75: DeprecationWarning: use options instead of chrome_options
# 0
# https://www.quora.com/topic/spicejet
# https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide
# https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines
# https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time
# https://www.quora.com/What-is-your-worst-SpiceJet-experience
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/How-do-I-board-a-domestic-SpiceJet-flight-from-Bagdogra-What-is-web-check-in-What-are-baggage-requirements-Can-I-bring-shampoo-and-conditioner-bottles-in-my-trolley-Im-boarding-a-flight-for-the-first-time-I-dont
# 9
# Which airlines will be worst affected by the grounding of Boeing 737 Max 8 in terms of revenue worldwide?
# Answer :
# I would think that Southwest Airlines would be the worst affected. Flying one type of aircraft does reduce cost but is a problem when this happens. The upside is that their pilots are very experienced and could probably cope with this situation better than the Ethiopian pilots.
# Lachie Smith
# Rodney Faubion
# **************************************************
# Answer :
# originally answered “Why does the spice jet aircraft carry the name ‘Mango’ at the front?”
# VT-SLE Boeing 737–8EH operating for Spicejet as ‘Mango Powder’ [1]
# Major Carriers like Air India, Air New Zealand, Lufthansa, British Airways, KLM (just to name a few) all ‘name’ their aircraft. This is an exclusive trait and is not mandated by the law.
# Spicejet , as the name suggests name all their aircraft after ‘spices’.
# Here are a few more from my collection
# VT-SGY Boeing 737–8GJ operating for Spicejet as ‘Cayenne’ [2]
# VT-SGQ Boeing 737–8GJ operating for Spicejet as ‘Celery’ [3]
# < Krishna Darshan Raghavan >
# References :
# [1] : VT-SLE | Boeing 737-8EH | SpiceJet | Prashob Chandran | JetPhotos
# [2],[3] : my phone
# Answer :
# I’m not sure that they do. Maybe you’re thinking of Mango Airlines, operated by SAA?
# Hope this helps!
# Krishna Darshan Raghavan
# Lachie Smith
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# Niranjan Renati
# **************************************************
# How do I claim a damaged baggage claim from SpiceJet Airlines?
# Alex Hidveghy
# **************************************************
# How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time?
# Answer :
# As mentioned in Ravi's answer to How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time? 60 minutes is risky. Are you flying for the first time? If yes then I would definitely not want to depend on a 60 minute gap.
# Plus think of this - if your first flight gets late, your second one is not going to wait for you (as you mention they are different airlines).
# Get a later flight.
# Answer :
# It is risky. If that involves a terminal change then you'll need to hope your first leg isn't delayed, you get your checked in baggage on time and then rush towards your connecting flight.
# Answer :
# I will carry my bag no baggage check in and please guide me if I do web check-in, will it save my time?
# Ravi
# Jackson Christie
# Robin Alton
# Justin Francis
# Shivendra Singh
# Shivendra Singh
# **************************************************
# What is your worst SpiceJet experience?
# Answer :
# LCC EXPERIENCE AT SPICEJET | KOCHI TO MUMBAI | SPICEJET LOUNGE
# DO WATCH THIS VIDEO ON MY EXPERIENCE AT SPICEJET.
# Vikky Agrawal
# Shailaja K Jagadeesh
# Suyog Thengale
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# Niranjan Renati
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# Niranjan Renati
# Jagan
# **************************************************
# How do I board a domestic SpiceJet flight from Bagdogra? What is web check-in? What are baggage requirements? Can I bring shampoo and conditioner bottles in my trolley? I'm boarding a flight for the first time & I don't want to be embarrassed later.
# Patrick Lee
# **************************************************
# Lachie Smith
#
#
#
# Lachie Smith
# 0 0 1 0
# Rodney Faubion
# Aircraft Maintenance Technician at Delta Air Lines
#
# Atlanta, GA
# Rodney Faubion Aircraft Maintenance Technician at Delta Air Lines
# 5 0 0 5
# Krishna Darshan Raghavan
#
#
#
# Krishna Darshan Raghavan
# 0 0 0 0
# Lachie Smith
#
#
#
# Lachie Smith
# 0 0 1 0
# Barnali Ghai
#
#
#
# Barnali Ghai
# 2 1 1 0
# Niranjan Renati
# Bouncing Ideas around
#
# Accra, Ghana
# Niranjan Renati Bouncing Ideas around
# 46 6 36 4
# Alex Hidveghy
#
#
#
# Alex Hidveghy
# 37 1 2 0
# Ravi
#
#
#
# Ravi
# 0 0 0 0
# Jackson Christie
#
#
#
# Jackson Christie
# 0 0 0 0
# Robin Alton
# Airline & hotel status, international travel experience
#
# St. Louis, MO
# Robin Alton Airline & hotel status, international travel experience
# 2561 2 60 28
# Justin Francis
#
#
#
# Justin Francis
# 0 0 6 0
# Shivendra Singh
#
#
#
# Shivendra Singh
# 0 0 37 0
# Shivendra Singh
#
#
#
# Shivendra Singh
# 0 0 37 0
# Vikky Agrawal
# Engineer, Learner.
# Birla Institute of Technology, Mesra
# Gurugram, Haryana, India
# Vikky Agrawal Engineer, Learner.
# 37 3 58 234
# Shailaja K Jagadeesh
# An Expert in anything was once a beginner
#
#
# Shailaja K Jagadeesh An Expert in anything was once a beginner
# 0 2 3 0
# Suyog Thengale
# Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer
#
# Navi Mumbai, Maharashtra, India
# Suyog Thengale Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer
# 116 5 244 21
# Barnali Ghai
#
#
#
# Barnali Ghai
# 0 1 1 0
# Niranjan Renati
# Bouncing Ideas around
#
# Accra, Ghana
# Niranjan Renati Bouncing Ideas around
# 46 6 36 4
# Barnali Ghai
#
#
#
# Barnali Ghai
# 0 1 1 0
# Niranjan Renati
# Bouncing Ideas around
#
# Accra, Ghana
# Niranjan Renati Bouncing Ideas around
# 46 6 36 4
# Jagan
#
#
#
# Jagan
# 0 0 0 0
# Patrick Lee
#
#
#
# Patrick Lee
# 0 0 24 0
# [('Lachie Smith', '', '', '', 0, 0, 1, 0), 'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide']
# [('Rodney Faubion', 'Aircraft Maintenance Technician at Delta Air Lines', '', 'Atlanta, GA', 5, 0, 0, 5), 'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide']
# [('Krishna Darshan Raghavan', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front']
# [('Lachie Smith', '', '', '', 0, 0, 1, 0), 'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front']
# [('Barnali Ghai', '', '', '', 2, 1, 1, 0), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Niranjan Renati', 'Bouncing Ideas around', '', 'Accra, Ghana', 46, 6, 36, 4), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Alex Hidveghy', '', '', '', 37, 1, 2, 0), 'https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines']
# [('Ravi', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Jackson Christie', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Robin Alton', 'Airline & hotel status, international travel experience', '', 'St. Louis, MO', 2561, 2, 60, 28), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Justin Francis', '', '', '', 0, 0, 6, 0), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Shivendra Singh', '', '', '', 0, 0, 37, 0), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Shivendra Singh', '', '', '', 0, 0, 37, 0), 'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time']
# [('Vikky Agrawal', 'Engineer, Learner.', 'Birla Institute of Technology, Mesra', 'Gurugram, Haryana, India', 37, 3, 58, 234), 'https://www.quora.com/What-is-your-worst-SpiceJet-experience']
# [('Shailaja K Jagadeesh', 'An Expert in anything was once a beginner', '', '', 0, 2, 3, 0), 'https://www.quora.com/What-is-your-worst-SpiceJet-experience']
# [('Suyog Thengale', 'Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer', '', 'Navi Mumbai, Maharashtra, India', 116, 5, 244, 21), 'https://www.quora.com/What-is-your-worst-SpiceJet-experience']
# [('Barnali Ghai', '', '', '', 0, 1, 1, 0), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Niranjan Renati', 'Bouncing Ideas around', '', 'Accra, Ghana', 46, 6, 36, 4), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Barnali Ghai', '', '', '', 0, 1, 1, 0), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Niranjan Renati', 'Bouncing Ideas around', '', 'Accra, Ghana', 46, 6, 36, 4), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Jagan', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India']
# [('Patrick Lee', '', '', '', 0, 0, 24, 0), 'https://www.quora.com/How-do-I-board-a-domestic-SpiceJet-flight-from-Bagdogra-What-is-web-check-in-What-are-baggage-requirements-Can-I-bring-shampoo-and-conditioner-bottles-in-my-trolley-Im-boarding-a-flight-for-the-first-time-I-dont']

# %% [markdown]
# # 2.prediction

# %%
question=pd.read_csv("questions.csv")
question = question.loc[:, ~question.columns.str.contains('^Unnamed')]

# %%
question.isnull().any()
# question.columns
import datetime as dt
import nltk
start = dt.datetime.now()
sno=nltk.stem.SnowballStemmer("english")
i=0
str1=""
final_string=[]
all_positive_words=[]
all_negative_words=[]
s=""
from nltk.corpus import stopwords
stop=set(stopwords.words('english'))
excluding = ['against','not','don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't",
             'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 
             'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",'shouldn', "shouldn't", 'wasn',
             "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
stop = [words for words in stop if words not in excluding]

import re
def cleanhtml(sentence):
    cleanr=re.compile('<.*>')
    cleantext=re.sub(cleanr,'',sentence)
    return cleantext
def cleanpunc(sentence):
    cleaned=re.sub(r'[?|!|\'|"|#]',r' ',sentence) #seee \' and combination
    cleaned=re.sub(r'[.|,|)|/|\|(]',r' ',cleaned)
    return cleaned
print(sno.stem("tasty"))#checking the rootword of tasty

print(sno)


import ipywidgets as widgets
def preprocess1(X):
    final_string=[]
    

    for sent in X:
        filterd_sentence=[]
        
        sent=str(sent)

        sent=cleanhtml(sent)
#         print(sent)
        for w in sent.split():
            for cleaned_words in cleanpunc(w).split():
                if((cleaned_words.isalpha())&(len(cleaned_words)>2)):
                    if(cleaned_words.lower() not in stop):
                        s=(sno.stem(cleaned_words.lower())).encode("utf8")
                        filterd_sentence.append(s)

                    else:
                        continue
                else:
                    continue

        str1= b" ".join(filterd_sentence)
        final_string.append(str1)
#         i=i+1
    return final_string


def preprocess(X):
    final_string=[]
    X=[X]

    for sent in X:
        filterd_sentence=[]
        
        sent=str(sent)

        sent=cleanhtml(sent)
#         print(sent)
        for w in sent.split():
            for cleaned_words in cleanpunc(w).split():
                if((cleaned_words.isalpha())&(len(cleaned_words)>2)):
                    if(cleaned_words.lower() not in stop):
                        s=(sno.stem(cleaned_words.lower())).encode("utf8")
                        filterd_sentence.append(s)

                    else:
                        continue
                else:
                    continue

        str1= b" ".join(filterd_sentence)
        final_string.append(str1)
#         i=i+1
    return final_string
# Out:
# tasti
# <nltk.stem.snowball.SnowballStemmer object at 0x0000024D4ECF3CF8>

# %%
question['cleaned']=question.text.apply(lambda x:preprocess(x))

# %%
import pickle
from keras.preprocessing import sequence
def find_word_index(row,word_index_dict):  
    holder = []
    for word in row.split():
        if word in word_index_dict:
            holder.append(word_index_dict[word]) 
        else:
            holder.append(0)            
    return holder
def predict_lstm(x):
    x=preprocess1(x)
#     print(x)
#     with open('model_lstm.pkl', 'rb') as f:
#         model = pickle.load(f)

#     print(model.predict[x])
    with open('label_transform.pkl', 'rb') as f:
        encoder= pickle.load(f)
        
    from keras.models import load_model
    model = load_model('LSTM_1.ckpt')
        
    with open('word_index_dict.pkl', 'rb') as f:
        word_index_dict= pickle.load(f)
        
    text=[]
    for sent in x:
        text.append(find_word_index(sent,word_index_dict))
        
        
        
  
    #print(len(x),len(text))  
    x=sequence.pad_sequences(text, maxlen=500)
    
    
        
    
    
    
    
    pred_prob=model.predict(x)
    
#     print(pred_prob)
#     print(encoder.classes_)
    
    
    sentiment=[]
    
#     print(encoder.inverse_transform(pred_prob))
    
    preds=encoder.inverse_transform(pred_prob)
    
    for pre in preds:
        if pre==1:
            sentiment.append("Strongly Negative")
        if pre==2:
            sentiment.append("Weekly Negative")
        if pre==3:
            sentiment.append("Neutral")
        if pre==4:
            sentiment.append("Weekly Positive")
        if pre==5:
            sentiment.append("Strongly Positive")
    
  
            
        
    


    
    
#     print("output::",pred)
    
        
    return [sentiment,pred_prob]
# Out:
# Using TensorFlow backend.
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
q=predict_lstm(list(question.cleaned))
question['sentiment']=q[0]


import numpy as np

question['confidence']=q[1].tolist()
# Out:
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
question.drop('cleaned', axis=1, inplace=True)

# %%
question = question.astype(str)
question.head()
question.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
# text          15 non-null object
# link          15 non-null object
# sentiment     15 non-null object
# confidence    15 non-null object
# dtypes: object(4)
# memory usage: 560.0+ bytes

# %% [markdown]
# # 3.Storing in DataBase

# %%
import mysql.connector as mysql
# question=pd.read_csv("question.csv")
# question = question.loc[:, ~question.columns.str.contains('^Unnamed')]
mydb = mysql.connect(
  host="127.0.0.1",
  user="sai",
  passwd="rgukt123",
    port="3309"
)

print(mydb)


mycursor = mydb.cursor()



try:
    mycursor.execute("CREATE DATABASE bot")
except:
    print("Database named bot already exists")




mydb = mysql.connect(
  host="localhost",
  user="root",
  passwd="rgukt123",
  database="bot",
    port="3309"
    
)


mycursor = mydb.cursor()

sql = "DROP TABLE IF EXISTS Quora"

mycursor.execute(sql) 

mycursor.execute("CREATE TABLE Quora( question text, link text,sentiment varchar(20),confidence text)")



for i in question.index:
    if i==0:
        continue
    
    mycursor.execute('INSERT INTO Quora(question , link, sentiment,confidence)' \
          'VALUES("%s", "%s", "%s","%s")', 
          list(question[i-1:i].values[0]))
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000024D591EC400>
# Database named bot already exists

# %%
mycursor.execute("SELECT * FROM Quora")

myresult = mycursor.fetchall()

print(myresult)

for x in myresult:
  print(x)
# Out:
# [("'Which airlines will be worst affected by the grounding of Boeing 737 Max 8 in terms of revenue worldwide?'", "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'", "'Strongly Negative'", "'[0.459308922290802, 0.37679925560951233, 0.1241297721862793, 0.027113229036331177, 0.0051610469818115234]'"), ("'I would think that Southwest Airlines would be the worst affected. Flying one type of aircraft does reduce cost but is a problem when this happens. The upside is that their pilots are very experienced and could probably cope with this situation better than the Ethiopian pilots.'", "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'", "'Weekly Negative'", "'[0.1238240897655487, 0.5208530426025391, 0.3133487105369568, 0.02768293023109436, 0.0017154514789581299]'"), ("'originally answered “Why does the spice jet aircraft carry the name ‘Mango’ at the front?”\nVT-SLE Boeing 737–8EH operating for Spicejet as ‘Mango Powder’ [1]\nMajor Carriers like Air India, Air New Zealand, Lufthansa, British Airways, KLM (just to name a few) all ‘name’ their aircraft. This is an exclusive trait and is not mandated by the law.\nSpicejet , as the name suggests name all their aircraft after ‘spices’.\nHere are a few more from my collection\nVT-SGY Boeing 737–8GJ operating for Spicejet as ‘Cayenne’ [2]\nVT-SGQ Boeing 737–8GJ operating for Spicejet as ‘Celery’ [3]\n< Krishna Darshan Raghavan >\nReferences :\n[1] : VT-SLE | Boeing 737-8EH | SpiceJet | Prashob Chandran | JetPhotos\n[2],[3] : my phone'", "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'", "'Weekly Negative'", "'[0.1087503433227539, 0.30785512924194336, 0.23772552609443665, 0.21749144792556763, 0.2569010853767395]'"), ("'I’m not sure that they do. Maybe you’re thinking of Mango Airlines, operated by SAA?\nHope this helps!'", "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'", "'Weekly Negative'", "'[0.1749154031276703, 0.3638930916786194, 0.359424889087677, 0.07107901573181152, 0.021979808807373047]'"), ("'Is Spicejet a reliable and good airline for travel within India?'", "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'", "'Strongly Positive'", "'[0.012964695692062378, 0.02400776743888855, 0.045591384172439575, 0.23054128885269165, 0.5992565155029297]'"), ("'How do I claim a damaged baggage claim from SpiceJet Airlines?'", "'https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines'", "'Strongly Negative'", "'[0.6255682110786438, 0.32242196798324585, 0.146307110786438, 0.03373312950134277, 0.012193113565444946]'"), ("'How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time?'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Weekly Negative'", "'[0.15713396668434143, 0.4041648209095001, 0.29410094022750854, 0.0743451714515686, 0.02006736397743225]'"), ("'As mentioned in Ravi's answer to How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time? 60 minutes is risky. Are you flying for the first time? If yes then I would definitely not want to depend on a 60 minute gap.\nPlus think of this - if your first flight gets late, your second one is not going to wait for you (as you mention they are different airlines).\nGet a later flight.'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Neutral'", "'[0.01983371376991272, 0.11953452229499817, 0.33425515890121 ...
# ("'Which airlines will be worst affected by the grounding of Boeing 737 Max 8 in terms of revenue worldwide?'", "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'", "'Strongly Negative'", "'[0.459308922290802, 0.37679925560951233, 0.1241297721862793, 0.027113229036331177, 0.0051610469818115234]'")
# ("'I would think that Southwest Airlines would be the worst affected. Flying one type of aircraft does reduce cost but is a problem when this happens. The upside is that their pilots are very experienced and could probably cope with this situation better than the Ethiopian pilots.'", "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'", "'Weekly Negative'", "'[0.1238240897655487, 0.5208530426025391, 0.3133487105369568, 0.02768293023109436, 0.0017154514789581299]'")
# ("'originally answered “Why does the spice jet aircraft carry the name ‘Mango’ at the front?”\nVT-SLE Boeing 737–8EH operating for Spicejet as ‘Mango Powder’ [1]\nMajor Carriers like Air India, Air New Zealand, Lufthansa, British Airways, KLM (just to name a few) all ‘name’ their aircraft. This is an exclusive trait and is not mandated by the law.\nSpicejet , as the name suggests name all their aircraft after ‘spices’.\nHere are a few more from my collection\nVT-SGY Boeing 737–8GJ operating for Spicejet as ‘Cayenne’ [2]\nVT-SGQ Boeing 737–8GJ operating for Spicejet as ‘Celery’ [3]\n< Krishna Darshan Raghavan >\nReferences :\n[1] : VT-SLE | Boeing 737-8EH | SpiceJet | Prashob Chandran | JetPhotos\n[2],[3] : my phone'", "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'", "'Weekly Negative'", "'[0.1087503433227539, 0.30785512924194336, 0.23772552609443665, 0.21749144792556763, 0.2569010853767395]'")
# ("'I’m not sure that they do. Maybe you’re thinking of Mango Airlines, operated by SAA?\nHope this helps!'", "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'", "'Weekly Negative'", "'[0.1749154031276703, 0.3638930916786194, 0.359424889087677, 0.07107901573181152, 0.021979808807373047]'")
# ("'Is Spicejet a reliable and good airline for travel within India?'", "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'", "'Strongly Positive'", "'[0.012964695692062378, 0.02400776743888855, 0.045591384172439575, 0.23054128885269165, 0.5992565155029297]'")
# ("'How do I claim a damaged baggage claim from SpiceJet Airlines?'", "'https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines'", "'Strongly Negative'", "'[0.6255682110786438, 0.32242196798324585, 0.146307110786438, 0.03373312950134277, 0.012193113565444946]'")
# ("'How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time?'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Weekly Negative'", "'[0.15713396668434143, 0.4041648209095001, 0.29410094022750854, 0.0743451714515686, 0.02006736397743225]'")
# ("'As mentioned in Ravi's answer to How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time? 60 minutes is risky. Are you flying for the first time? If yes then I would definitely not want to depend on a 60 minute gap.\nPlus think of this - if your first flight gets late, your second one is not going to wait for you (as you mention they are different airlines).\nGet a later flight.'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Neutral'", "'[0.01983371376991272, 0.11953452229499817, 0.3342551589012146, 0.276695191860199, 0.19061163067817688]'")
# ("'It is risky. If that involves a terminal change then you'll need to hope your first leg isn't delayed, you get your checked in baggage on time and then rush towards your connecting flight.'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Weekly Negative'", "'[0.1807938516139984, 0.5518955588340759, 0.1933038830757141, 0.027707546949386597, 0.007010012865066528]'")
# ("'I will carry my bag no baggage check in and please guide me if I do web check-in, will it save my time?'", "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'", "'Strongly Positive'", "'[0.1674746870994568, 0.17856758832931519, 0.155492901802063, 0.14482614398002625, 0.34005317091941833]'")
# ("'What is your worst SpiceJet experience?'", "'https://www.quora.com/What-is-your-worst-SpiceJet-experience'", "'Strongly Negative'", "'[0.8936124444007874, 0.16348937153816223, 0.02270534634590149, 0.009452611207962036, 0.015021681785583496]'")
# ("'LCC EXPERIENCE AT SPICEJET | KOCHI TO MUMBAI | SPICEJET LOUNGE\nDO WATCH THIS VIDEO ON MY EXPERIENCE AT SPICEJET.'", "'https://www.quora.com/What-is-your-worst-SpiceJet-experience'", "'Strongly Positive'", "'[0.2033260464668274, 0.21182578802108765, 0.11904096603393555, 0.13012686371803284, 0.25113776326179504]'")
# ("'Is Spicejet a reliable and good airline for travel within India?'", "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'", "'Strongly Positive'", "'[0.012964695692062378, 0.02400776743888855, 0.045591384172439575, 0.23054128885269165, 0.5992565155029297]'")
# ("'Is Spicejet a reliable and good airline for travel within India?'", "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'", "'Strongly Positive'", "'[0.012964695692062378, 0.02400776743888855, 0.045591384172439575, 0.23054128885269165, 0.5992565155029297]'")

# %%
import pandas as pd
df=pd.read_csv("user_details.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.columns
# Out:
# Index(['name', 'description', 'education', 'lives_in', 'num_answers',
#        'num_questions', 'num_followers', 'num_following', 'link'],
#       dtype='object')

# %%
df.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
# name             22 non-null object
# description      8 non-null object
# education        1 non-null object
# lives_in         7 non-null object
# num_answers      22 non-null int64
# num_questions    22 non-null int64
# num_followers    22 non-null int64
# num_following    22 non-null int64
# link             22 non-null object
# dtypes: int64(4), object(5)
# memory usage: 1.6+ KB

# %%
import mysql.connector as mysql
df=pd.read_csv("user_details.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
mydb = mysql.connect(
  host="127.0.0.1",
  user="sai",
  passwd="rgukt123",
    port="3309"
)

print(mydb)


mycursor = mydb.cursor()



try:
    mycursor.execute("CREATE DATABASE bot")
except:
    print("Database named bot already exists")




mydb = mysql.connect(
  host="localhost",
  user="root",
  passwd="rgukt123",
  database="bot",
    port="3309"
    
)


mycursor = mydb.cursor()

sql = "DROP TABLE IF EXISTS Quora_User_Details"

mycursor.execute(sql) 

mycursor.execute("CREATE TABLE Quora_User_Details( name text, description text, education text, lives_in text, num_answers text,num_questions text , num_followers text, num_following text,link text)")



for i in df.index:
#     print(i)
    if i==0:
        continue
    
    mycursor.execute('INSERT INTO Quora_User_Details(name , description, education , lives_in , num_answers ,num_questions , num_followers , num_following,link)' \
          'VALUES("%s", "%s","%s","%s","%s","%s","%s","%s","%s")', 
          list(df[i-1:i].values[0]))
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000024D4ECF3A90>
# Database named bot already exists

# %% [markdown]
# # 4.Retrivig From DataBase

# %%
mycursor.execute("SELECT * FROM Quora")

myresult = mycursor.fetchall()

print(myresult)

for x in myresult:
  print(x)
# Out:
# []

# %%
mycursor.execute("SELECT * FROM Quora_User_Details")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ("'Lachie Smith'", 'nan', 'nan', 'nan', '0', '0', '1', '0', "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'")
# ("'Rodney Faubion'", "'Aircraft Maintenance Technician at Delta Air Lines'", 'nan', "'Atlanta, GA'", '5', '0', '0', '5', "'https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide'")
# ("'Krishna Darshan Raghavan'", 'nan', 'nan', 'nan', '0', '0', '0', '0', "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'")
# ("'Lachie Smith'", 'nan', 'nan', 'nan', '0', '0', '1', '0', "'https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front'")
# ("'Barnali Ghai'", 'nan', 'nan', 'nan', '2', '1', '1', '0', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Niranjan Renati'", "'Bouncing Ideas around'", 'nan', "'Accra, Ghana'", '46', '6', '36', '4', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Alex Hidveghy'", 'nan', 'nan', 'nan', '37', '1', '2', '0', "'https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines'")
# ("'Ravi'", 'nan', 'nan', 'nan', '0', '0', '0', '0', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Jackson Christie'", 'nan', 'nan', 'nan', '0', '0', '0', '0', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Robin Alton'", "'Airline & hotel status, international travel experience'", 'nan', "'St. Louis, MO'", '2561', '2', '60', '28', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Justin Francis'", 'nan', 'nan', 'nan', '0', '0', '6', '0', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Shivendra Singh'", 'nan', 'nan', 'nan', '0', '0', '37', '0', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Shivendra Singh'", 'nan', 'nan', 'nan', '0', '0', '37', '0', "'https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time'")
# ("'Vikky Agrawal'", "'Engineer, Learner.'", "'Birla Institute of Technology, Mesra'", "'Gurugram, Haryana, India'", '37', '3', '58', '234', "'https://www.quora.com/What-is-your-worst-SpiceJet-experience'")
# ("'Shailaja K Jagadeesh'", "'An Expert in anything was once a beginner'", 'nan', 'nan', '0', '2', '3', '0', "'https://www.quora.com/What-is-your-worst-SpiceJet-experience'")
# ("'Suyog Thengale'", "'Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer'", 'nan', "'Navi Mumbai, Maharashtra, India'", '116', '5', '244', '21', "'https://www.quora.com/What-is-your-worst-SpiceJet-experience'")
# ("'Barnali Ghai'", 'nan', 'nan', 'nan', '0', '1', '1', '0', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Niranjan Renati'", "'Bouncing Ideas around'", 'nan', "'Accra, Ghana'", '46', '6', '36', '4', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Barnali Ghai'", 'nan', 'nan', 'nan', '0', '1', '1', '0', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Niranjan Renati'", "'Bouncing Ideas around'", 'nan', "'Accra, Ghana'", '46', '6', '36', '4', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")
# ("'Jagan'", 'nan', 'nan', 'nan', '0', '0', '0', '0', "'https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India'")

# %%
# import time
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# import csv



# link1 = input("Enter first link")
# #link2 = input("Enter second link")
# manylinks = list()
# manylinks.append(link1)
# #manylinks.append(link2)
# for olink in manylinks:
#     qlinks = list()    
#     browser = webdriver.Chrome(executable_path='chromedriver')
#     browser.get(olink)
#     time.sleep(1)
#     elem = browser.find_element_by_tag_name("body")


#     no_of_pagedowns = 50
#     while no_of_pagedowns:
#         elem.send_keys(Keys.PAGE_DOWN)
#         time.sleep(0.2)
#         no_of_pagedowns-=1
#     post_elems =browser.find_elements_by_xpath("//a[@class='question_link']")
#     for post in post_elems:
#         qlink = post.get_attribute("href")
#         print(qlink)
#         qlinks.append(qlink)

#     for qlink in qlinks:

#         append_status=0

#         row = list()

#         browser.get(qlink)
#         time.sleep(1)


#         elem = browser.find_element_by_tag_name("body")


#         no_of_pagedowns = 1
#         while no_of_pagedowns:
#             elem.send_keys(Keys.PAGE_DOWN)
#             time.sleep(0.2)
#             no_of_pagedowns-=1


# #         #Question Names
# #         qname =browser.find_elements_by_xpath("//div[@class='question_text_edit']")
# #         for q in qname:
# #             print(q.text)
# #             row.append(q.text)
#         qname =browser.find_elements_by_xpath("//div[@class='user']")
#         for q in qname:
#             print(q.text)
#             row.append(q.text)

# %%
# import time
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# import csv
# browser = webdriver.Chrome(executable_path='chromedriver')
# browser.get("https://www.quora.com/Is-getting-a-masters-or-a-PhD-necessary-to-get-into-top-AI-ML-research-groups-like-FAIR-or-DeepMind")
# users =browser.find_elements_by_xpath("//div[@class='user']")
# users
# browser.quit()

# %%
# import time
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# import csv
# browser = webdriver.Chrome(executable_path='chromedriver')
# browser.get("https://www.quora.com/Is-getting-a-masters-or-a-PhD-necessary-to-get-into-top-AI-ML-research-groups-like-FAIR-or-DeepMind")
# # name_and_signature =browser.find_element_by_class_name('ProfileNameAndSig')
# name =browser.find_element_by_class_name('user').text
# time.sleep(3)


# print(name)
# # print(description)
# browser.quit()

# %%
# browser = webdriver.Chrome(executable_path='chromedriver')
# s="";
# for i in name.split():
#     s+="-"+i
# browser.get("https://www.quora.com/profile/"+s[1:])
# description = browser.find_element_by_class_name('UserCredential').text
# credentials_and_highlights = browser.find_element_by_class_name('AboutSection')
# try:
#         education = credentials_and_highlights.find_element_by_class_name('SchoolCredentialListItem')
#         education = re.sub(r'Studied at', '', education.find_element_by_class_name('UserCredential').text).strip()
# except:
#         education = ''
# try:
#         lives_in = credentials_and_highlights.find_element_by_class_name('LocationCredentialListItem')
#         lives_in = re.sub(r'Lives in', '', lives_in.find_element_by_class_name('UserCredential').text).strip()
# except:
#         lives_in = ''
# try:
#         work = credentials_and_highlights.find_element_by_class_name('WorkCredentialListItem')
#         work = work.find_element_by_class_name('UserCredential')
# except:
#         work = ''
# print(name)
# print(description)
# print(credentials_and_highlights)
# print(education)
# print(lives_in)
# print(work)
# browser.quit()

# %%
# def info(name):
#         driver = webdriver.Chrome(executable_path='chromedriver')
#         s="";
#         for i in name.split():
#             s+="-"+i
#         import re
#         try:
#             driver.get("https://www.quora.com/profile/"+s[1:])
#         except:
#             return
#         try:
#             description = driver.find_element_by_class_name('UserCredential').text
#         except:
#             description=""
#         try:
#             credentials_and_highlights = driver.find_element_by_class_name('AboutSection')
#         except:
#             credentials_and_highlights=""
            
            
#         try:
#                 education = credentials_and_highlights.find_element_by_class_name('SchoolCredentialListItem')
#                 education = re.sub(r'Studied at', '', education.find_element_by_class_name('UserCredential').text).strip()
#         except:
#                 education = ''
#         try:
#                 lives_in = credentials_and_highlights.find_element_by_class_name('LocationCredentialListItem')
#                 lives_in = re.sub(r'Lives in', '', lives_in.find_element_by_class_name('UserCredential').text).strip()
#         except:
#                 lives_in = ''
       
#         print(name)
#         print(description)
#         print(education)
#         print(lives_in)
        
#         try:
#             num_answers = int(re.sub('\D', '', driver.find_element_by_class_name('AnswersNavItem').find_element_by_class_name('list_count').text))
#         except:
#             num_answers=0
#         try:
#             num_questions = int(re.sub('\D', '', driver.find_element_by_class_name('QuestionsNavItem').find_element_by_class_name('list_count').text))
#         except:
#             num_questions=0
        
#         try:
#             num_followers = int(re.sub('\D', '', driver.find_element_by_class_name('FollowersNavItem').find_element_by_class_name('list_count').text))
#         except:
#             num_followers=0
#         try:
#             num_following = int(re.sub('\D', '', driver.find_element_by_class_name('FollowingNavItem').find_element_by_class_name('list_count').text))
#         except:
#             num_following=0
#         try:
#            num_topics = int(re.sub('\D', '', driver.find_element_by_class_name('TopicsNavItem').find_element_by_class_name('list_count').text))
#         except:
#             num_topics=0

 
            
            
#         print(name,description)
#         print(num_answers,num_questions,num_followers,num_following)
        
#         return name,description,education,lives_in,num_answers,num_questions,num_followers,num_following



#         driver.quit()

# %%
# import time
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# import csv
# import pandas as pd
# manylinks=[]
# usernames=[]
# def scrapper_quora(sentence):
#     import spacy
#     import nltk
#     nltk.download('averaged_perceptron_tagger')

#     nlp = spacy.load('en_core_web_sm')

#     import re
#     l=[]
#     k=[]
#     d=[]
#     cnt=0

#     punctuations = '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~'
#     texts = []
#     #for i in b:
#     rev=re.sub('[^a-zA-Z]',' ',str(sentence))
#     rev=rev.lower();
#     doc = nlp(rev, disable=['parser', 'ner'])
#     tokens = [tok.lemma_.lower().strip() for tok in doc if tok.lemma_ != '-PRON-']
#     tokens = [tok for tok in tokens if tok not in nlp.Defaults.stop_words and tok not in punctuations]
#     #tokens = ' '.join(tokens)
#     #texts.append(tokens)
#     '''
#     tagged = nltk.pos_tag(tokens)
#     print(tagged)
#     a=[]
#     for i in tagged:
#         log = (i[1][0] == 'N')
#         if log == True:
#           a.append(i[0])
#     print("this is a",a)
#     '''
#     sk = set(tokens)
#     print("this is sk",sk)
#     print(tokens)
    
#     for i in sk:
#         manylinks.append("https://www.quora.com/topic/"+str(i))
    
    
# #     link1 = "https://www.quora.com/topic/"+keyword
# #     #link2 = input("Enter second link")
# #     manylinks = list()
# #     manylinks.append(link1)
#     #manylinks.append(link2)
    
#     ques=[]
#     ques_no=[]
   
    
#     qusers=[]
#     user_details=[]

    
#     ful=[]
#     ans_no=[]
#     ans=[]
#     ful1=[]
#     count=1
    
#     for olink in manylinks:
#         qlinks = list()
#         print(olink)
#         options = webdriver.ChromeOptions()
#         options.binary_location = "C:/Program Files (x86)/Google/Chrome/Application/chrome.exe"
#         browser = webdriver.Chrome(executable_path=r'C:\Users\saireddyavs\Desktop\twitter bot\twitter_scrapper\chromedriver', chrome_options=options)
#         try:
#             browser.get(olink)
#         except:
#             continue
#         time.sleep(1)
#         elem = browser.find_element_by_tag_name("body")


#         no_of_pagedowns = 50
#         while no_of_pagedowns:
#             elem.send_keys(Keys.PAGE_DOWN)
#             time.sleep(0.2)
#             no_of_pagedowns-=1
#         post_elems =browser.find_elements_by_xpath("//a[@class='question_link']")
#         for post in post_elems:
#             qlink = post.get_attribute("href")
#             print(qlink)
#             qlinks.append(qlink)
        
#         print(len(qlinks))

#         for qlink in qlinks:

#             append_status=0

#             row = list()
            
#             us=[]
            
            

#             browser.get(qlink)
#             time.sleep(1)


#             elem = browser.find_element_by_tag_name("body")


#             no_of_pagedowns = 1
#             while no_of_pagedowns:
#                 elem.send_keys(Keys.PAGE_DOWN)
#                 time.sleep(0.2)
#                 no_of_pagedowns-=1


#     #         #Question Names
#     #         qname =browser.find_elements_by_xpath("//div[@class='question_text_edit']")
#     #         for q in qname:
#     #             print(q.text)
#     #             row.append(q.text)
#             qname =browser.find_elements_by_xpath("//div[@class='question_text_edit']")
#             for q in qname:
                
#                 k1=0
#                 for i in sk:
#                     if i in q.text.lower():
#                         k1+=1
                        
#                 if k1>=len(sk)/2:
#                     qq=q.text
#                     ful.append([qq,qlink])
#                     print(q.text)
                    
                

#             all_ans=browser.find_elements_by_xpath("//div[@class='ui_qtext_expanded']")
#             i=1
#             answer_field = list()
#             for post in all_ans:
#                 if True:
                    
                    
#                     k2=0
#                     for i in sk:
#                         if i in post.text.lower():
#                             k2+=1
#                     if k2>=len(sk)/2:
# #                         row.append(post.text)
# #                         ans.append(post.text)
# #                         ans_no.append("answer to question_"+str(count))
#                         print("Answer : ")
#                         print(post.text)

#                         ful.append([post.text,qlink])
                
                        
        
                    
                    
#                 else:
#                     break

            
            
#             if k1<len(sk)/2 and k2<len(sk)/2:
#                 continue
            
                
#             try:
                
#                 name=browser.find_elements_by_xpath("//a[@class='user']")
                
#                 for i in name:
#                     print(i.text)
#                     usernames.append([i.text,qlink])
#                     us.append(i.text)
                    
                
               
#             except:
#                 name=""
#                 print("name not came")
            
            
            
            
            
            
            


#            # print(row)
            

            

#             print("*"*50)
#             count+=1

#         browser.quit() 

#         df=pd.DataFrame(ful,columns=["text","link"])
#         df.to_csv("questions.csv")
# #         df=pd.DataFrame(ful1,columns=['answer',"answers_number"])
# #         df.to_csv("answers.csv")

        
        
        
        
#         user_details=[]
#         for i in usernames:
#             user_details.append([info(i[0]),i[1]])
        
#         users=[]
#         for i in user_details:
#             print(i)
#             l=list(i[0])
#             l.append(i[1])
#             users.append(l)

#         df=pd.DataFrame(users,columns=["name","description","education","lives_in","num_answers","num_questions","num_followers","num_following","link"])


#         df.fillna("")

#         df.to_csv("user_details.csv")

# %%
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\saireddyavs\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# this is sk {'spicejet', 'airline'}
# ['spicejet', 'airline']
# https://www.quora.com/topic/spicejet
# C:\Users\saireddyavs\Anaconda3\envs\gpuu\lib\site-packages\ipykernel_launcher.py:74: DeprecationWarning: use options instead of chrome_options
# https://www.quora.com/Which-airlines-will-be-worst-affected-by-the-grounding-of-Boeing-737-Max-8-in-terms-of-revenue-worldwide
# https://www.quora.com/Why-does-the-spice-jet-aircraft-carry-the-name-Mango-at-the-front
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/How-do-I-claim-a-damaged-baggage-claim-from-SpiceJet-Airlines
# https://www.quora.com/How-do-I-catch-a-connecting-flight-with-a-different-airline-Indigo-SpiceJet-Domestic-with-a-60-minute-gap-Is-it-risky-or-okay-as-it-s-my-first-time
# https://www.quora.com/What-is-your-worst-SpiceJet-experience
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/Is-Spicejet-a-reliable-and-good-airline-for-travel-within-India
# https://www.quora.com/How-do-I-board-a-domestic-SpiceJet-flight-from-Bagdogra-What-is-web-check-in-What-are-baggage-requirements-Can-I-bring-shampoo-and-conditioner-bottles-in-my-trolley-Im-boarding-a-flight-for-the-first-time-I-dont
# 9
# Which airlines will be worst affected by the grounding of Boeing 737 Max 8 in terms of revenue worldwide?
# Answer :
# I would think that Southwest Airlines would be the worst affected. Flying one type of aircraft does reduce cost but is a problem when this happens. The upside is that their pilots are very experienced and could probably cope with this situation better than the Ethiopian pilots.
# Lachie Smith
# Rodney Faubion
# **************************************************
# Answer :
# originally answered “Why does the spice jet aircraft carry the name ‘Mango’ at the front?”
# VT-SLE Boeing 737–8EH operating for Spicejet as ‘Mango Powder’ [1]
# Major Carriers like Air India, Air New Zealand, Lufthansa, British Airways, KLM (just to name a few) all ‘name’ their aircraft. This is an exclusive trait and is not mandated by the law.
# Spicejet , as the name suggests name all their aircraft after ‘spices’.
# Here are a few more from my collection
# VT-SGY Boeing 737–8GJ operating for Spicejet as ‘Cayenne’ [2]
# VT-SGQ Boeing 737–8GJ operating for Spicejet as ‘Celery’ [3]
# < Krishna Darshan Raghavan >
# References :
# [1] : VT-SLE | Boeing 737-8EH | SpiceJet | Prashob Chandran | JetPhotos
# [2],[3] : my phone
# Answer :
# I’m not sure that they do. Maybe you’re thinking of Mango Airlines, operated by SAA?
# Hope this helps!
# Krishna Darshan Raghavan
# Lachie Smith
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# **************************************************
# How do I claim a damaged baggage claim from SpiceJet Airlines?
# Alex Hidveghy
# **************************************************
# How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time?
# Answer :
# As mentioned in Ravi's answer to How do I catch a connecting flight with a different airline (Indigo SpiceJet, Domestic) with a 60-minute gap? Is it risky or okay as it’s my first time? 60 minutes is risky. Are you flying for the first time? If yes then I would definitely not want to depend on a 60 minute gap.
# Plus think of this - if your first flight gets late, your second one is not going to wait for you (as you mention they are different airlines).
# Get a later flight.
# Ravi
# Jackson Christie
# Robin Alton
# Justin Francis
# Shivendra Singh
# Shivendra Singh
# **************************************************
# What is your worst SpiceJet experience?
# Answer :
# LCC EXPERIENCE AT SPICEJET | KOCHI TO MUMBAI | SPICEJET LOUNGE
# DO WATCH THIS VIDEO ON MY EXPERIENCE AT SPICEJET.
# Vikky Agrawal
# Shailaja K Jagadeesh
# Suyog Thengale
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# Niranjan Renati
# **************************************************
# Is Spicejet a reliable and good airline for travel within India?
# Barnali Ghai
# Niranjan Renati
# **************************************************
# How do I board a domestic SpiceJet flight from Bagdogra? What is web check-in? What are baggage requirements? Can I bring shampoo and conditioner bottles in my trolley? I'm boarding a flight for the first time & I don't want to be embarrassed later.
# Patrick Lee
# **************************************************
# https://www.quora.com/topic/airline
# 0

# %%
# Out:
# Lachie Smith
#
#
#
# Lachie Smith
# 0 0 1 0
# Rodney Faubion
# Aircraft Maintenance Technician at Delta Air Lines
# Associates Aircraft Mechanic, Texas State Technical College
#
# Rodney Faubion Aircraft Maintenance Technician at Delta Air Lines
# 5 0 0 5
# Krishna Darshan Raghavan
#
#
#
# Krishna Darshan Raghavan
# 0 0 0 0
# Lachie Smith
#
#
#
# Lachie Smith
# 0 0 0 0
# Barnali Ghai
#
#
#
# Barnali Ghai
# 2 0 1 0
# Alex Hidveghy
#
#
#
# Alex Hidveghy
# 37 0 2 0
# Ravi
#
#
#
# Ravi
# 0 0 0 0
# Jackson Christie
#
#
#
# Jackson Christie
# 0 0 0 0
# Robin Alton
# Airline & hotel status, international travel experience
# Studied Human Resources at Indiana University
#
# Robin Alton Airline & hotel status, international travel experience
# 2558 2 60 28
# Justin Francis
#
#
#
# Justin Francis
# 0 0 6 0
# Shivendra Singh
#
#
#
# Shivendra Singh
# 0 0 37 0
# Shivendra Singh
#
#
#
# Shivendra Singh
# 0 0 37 0
# Vikky Agrawal
# Engineer, Learner.
# Birla Institute of Technology, Mesra
# Gurugram, Haryana, India
# Vikky Agrawal Engineer, Learner.
# 0 3 58 234
# Shailaja K Jagadeesh
# An Expert in anything was once a beginner
#
#
# Shailaja K Jagadeesh An Expert in anything was once a beginner
# 0 2 3 0
# Suyog Thengale
# Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer
# BA Computer Science & Physics, University of South Florida
# Navi Mumbai, Maharashtra, India
# Suyog Thengale Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer
# 0 5 244 21
# Barnali Ghai
#
#
#
# Barnali Ghai
# 2 0 1 0
# Niranjan Renati
# Bouncing Ideas around
# Little Flower English Medium School, Guntur
#
# Niranjan Renati Bouncing Ideas around
# 46 6 36 4
# Barnali Ghai
#
#
#
# Barnali Ghai
# 2 0 1 0
# Niranjan Renati
# Bouncing Ideas around
# Little Flower English Medium School, Guntur
# Accra, Ghana
# Niranjan Renati Bouncing Ideas around
# 46 6 36 4
# Patrick Lee
#
#
#
# Patrick Lee
# 0 0 0 0

# %%
# Out:
# [('Lachie Smith', '', '', '', 0, 0, 1, 0), 'https://www.quora.com/topic/spicejet']
# [('Rodney Faubion', 'Aircraft Maintenance Technician at Delta Air Lines', 'Associates Aircraft Mechanic, Texas State Technical College', '', 5, 0, 0, 5), 'https://www.quora.com/topic/spicejet']
# [('Krishna Darshan Raghavan', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/topic/spicejet']
# [('Lachie Smith', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/topic/spicejet']
# [('Barnali Ghai', '', '', '', 2, 0, 1, 0), 'https://www.quora.com/topic/spicejet']
# [('Alex Hidveghy', '', '', '', 37, 0, 2, 0), 'https://www.quora.com/topic/spicejet']
# [('Ravi', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/topic/spicejet']
# [('Jackson Christie', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/topic/spicejet']
# [('Robin Alton', 'Airline & hotel status, international travel experience', 'Studied Human Resources at Indiana University', '', 2558, 2, 60, 28), 'https://www.quora.com/topic/spicejet']
# [('Justin Francis', '', '', '', 0, 0, 6, 0), 'https://www.quora.com/topic/spicejet']
# [('Shivendra Singh', '', '', '', 0, 0, 37, 0), 'https://www.quora.com/topic/spicejet']
# [('Shivendra Singh', '', '', '', 0, 0, 37, 0), 'https://www.quora.com/topic/spicejet']
# [('Vikky Agrawal', 'Engineer, Learner.', 'Birla Institute of Technology, Mesra', 'Gurugram, Haryana, India', 0, 3, 58, 234), 'https://www.quora.com/topic/spicejet']
# [('Shailaja K Jagadeesh', 'An Expert in anything was once a beginner', '', '', 0, 2, 3, 0), 'https://www.quora.com/topic/spicejet']
# [('Suyog Thengale', 'Aviation Enthusiast | Film Maker | Travel Blogger | Dreamer', 'BA Computer Science & Physics, University of South Florida', 'Navi Mumbai, Maharashtra, India', 0, 5, 244, 21), 'https://www.quora.com/topic/spicejet']
# [('Barnali Ghai', '', '', '', 2, 0, 1, 0), 'https://www.quora.com/topic/spicejet']
# [('Niranjan Renati', 'Bouncing Ideas around', 'Little Flower English Medium School, Guntur', '', 46, 6, 36, 4), 'https://www.quora.com/topic/spicejet']
# [('Barnali Ghai', '', '', '', 2, 0, 1, 0), 'https://www.quora.com/topic/spicejet']
# [('Niranjan Renati', 'Bouncing Ideas around', 'Little Flower English Medium School, Guntur', 'Accra, Ghana', 46, 6, 36, 4), 'https://www.quora.com/topic/spicejet']
# [('Patrick Lee', '', '', '', 0, 0, 0, 0), 'https://www.quora.com/topic/spicejet']

# %%
# Out:
#                        name  \
# 0              Lachie Smith
# 1            Rodney Faubion
# 2  Krishna Darshan Raghavan
# 3              Lachie Smith
# 4              Barnali Ghai
#
#                                          description  \
# 0
# 1  Aircraft Maintenance Technician at Delta Air L...
# 2
# 3
# 4
#
#                                            education lives_in  num_answers  \
# 0                                                                        0
# 1  Associates Aircraft Mechanic, Texas State Tech...                     5
# 2                                                                        0
# 3                                                                        0
# 4                                                                        2
#
#    num_questions  num_followers  num_following  \
# 0              0              1              0
# 1              0              0              5
# 2              0              0              0
# 3              0              0              0
# 4              0              1              0
#
#                                    link
# 0  https://www.quora.com/topic/spicejet
# 1  https://www.quora.com/topic/spicejet
# 2  https://www.quora.com/topic/spicejet
# 3  https://www.quora.com/topic/spicejet
# 4  https://www.quora.com/topic/spicejet
